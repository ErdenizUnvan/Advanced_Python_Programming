# %%
#sehirler.txt dosyasini listeye'ye cevir
#liste icine her bir sehrin bilgileri dictionary olsun
#her bir sehir icin liste icinde
#[{'id':id,'sehir':sehir,'enlem':enlem,'boylam':boylam,'ulke':ulke}]
#latitude: enlem
#longitude: boylam
#liste icindeki dictionary'lerden ulke key'inin value'su TR olanlari
#yeni bir listeye ekle ve listeyi print et
#liste icinde kac tane dictionary var?

# %% [raw]
# #sonuc soyle olmali:
# uzunluk: 904
#
# [{'ID': '315985',
#   'isim': 'Edremit',
#   'enlem': '39.596111',
#   'boylam': '27.024441',
#   'ulke': 'TR'},
#  {'ID': '325363',
#   'isim': 'Adana',
#   'enlem': '37.001671',
#   'boylam': '35.328892',
#   'ulke': 'TR'},
#  {'ID': '298333',
#   'isim': 'Sanliurfa',
#   'enlem': '37.167080',
#   'boylam': '38.793919',
#   'ulke': 'TR'},
#  {'ID': '303195',
#   'isim': 'Osmaniye',
#   'enlem': '37.074169',
#   'boylam': '36.247780',
#   'ulke': 'TR'},
#  {'ID': '320392',
#   'isim': 'Burdur',
#   'enlem': '37.720280',
#   'boylam': '30.290831',
#   'ulke': 'TR'},
#  {'ID': '320995',
#   'isim': 'Bodrum',
#   'enlem': '37.038330',
#   'boylam': '27.429171',
#   'ulke': 'TR'},
#  {'ID': '308464',
#   'isim': 'Kayseri',
#   'enlem': '38.732220',
#   'boylam': '35.485279',
#   'ulke': 'TR'},
#  {'ID': '303290',
#   'isim': 'Ortakoy',
#   'enlem': '38.737282',
#   'boylam': '34.038658',
#   'ulke': 'TR'},
#  {'ID': '304827',
#   'isim': 'Manisa',
#   'enlem': '38.612019',
#   'boylam': '27.426460',
#   'ulke': 'TR'},
#  {'ID': '305268',
#   'isim': 'Kutahya',
#   'enlem': '39.424171',
#   'boylam': '29.983330',
#   'ulke': 'TR'},
#  {'ID': '325303',
#   'isim': 'Afyonkarahisar',
#   'enlem': '38.756672',
#   'boylam': '30.543329',
#   'ulke': 'TR'},
#  {'ID': '309647',
#   'isim': 'Agri',
#   'enlem': '39.719440',
#   'boylam': '43.051392',
#   'ulke': 'TR'},
#  {'ID': '322165',
#   'isim': 'Balikesir',
#   'enlem': '39.649170',
#   'boylam': '27.886110',
#   'ulke': 'TR'},
#  {'ID': '750598',
#   'isim': 'Bilecik',
#   'enlem': '40.141918',
#   'boylam': '29.979321',
#   'ulke': 'TR'},
#  {'ID': '743952',
#   'isim': 'Kars',
#   'enlem': '40.601990',
#   'boylam': '43.094952',
#   'ulke': 'TR'},
#  {'ID': '740264',
#   'isim': 'Samsun',
#   'enlem': '41.286671',
#   'boylam': '36.330002',
#   'ulke': 'TR'},
#  {'ID': '743882',
#   'isim': 'Kastamonu',
#   'enlem': '41.378052',
#   'boylam': '33.775280',
#   'ulke': 'TR'},
#  {'ID': '745044',
#   'isim': 'Istanbul',
#   'enlem': '41.013840',
#   'boylam': '28.949659',
#   'ulke': 'TR'},
#  {'ID': '315202',
#   'isim': 'Eskisehir',
#   'enlem': '39.776669',
#   'boylam': '30.520559',
#   'ulke': 'TR'},
#  {'ID': '738927',
#   'isim': 'Tekirdag',
#   'enlem': '40.978008',
#   'boylam': '27.508520',
#   'ulke': 'TR'},
#  {'ID': '306571',
#   'isim': 'Konya',
#   'enlem': '37.871349',
#   'boylam': '32.484638',
#   'ulke': 'TR'},
#  {'ID': '311073',
#   'isim': 'Isparta',
#   'enlem': '37.764439',
#   'boylam': '30.552219',
#   'ulke': 'TR'},
#  {'ID': '311046',
#   'isim': 'Izmir',
#   'enlem': '38.412731',
#   'boylam': '27.138380',
#   'ulke': 'TR'},
#  {'ID': '314830',
#   'isim': 'Gaziantep',
#   'enlem': '37.059441',
#   'boylam': '37.382500',
#   'ulke': 'TR'},
#  {'ID': '752850',
#   'isim': 'Adapazari',
#   'enlem': '40.780560',
#   'boylam': '30.403330',
#   'ulke': 'TR'},
#  {'ID': '741763',
#   'isim': 'Maltepe',
#   'enlem': '40.935669',
#   'boylam': '29.155069',
#   'ulke': 'TR'},
#  {'ID': '317109',
#   'isim': 'Denizli',
#   'enlem': '37.774170',
#   'boylam': '29.087500',
#   'ulke': 'TR'},
#  {'ID': '750269',
#   'isim': 'Bursa',
#   'enlem': '40.191669',
#   'boylam': '29.061110',
#   'ulke': 'TR'},
#  {'ID': '304922',
#   'isim': 'Malatya',
#   'enlem': '38.350182',
#   'boylam': '38.316669',
#   'ulke': 'TR'},
#  {'ID': '738743',
#   'isim': 'Tokat',
#   'enlem': '40.313889',
#   'boylam': '36.554440',
#   'ulke': 'TR'},
#  {'ID': '747014',
#   'isim': 'Gebze',
#   'enlem': '40.802761',
#   'boylam': '29.430679',
#   'ulke': 'TR'},
#  {'ID': '750516',
#   'isim': 'Bolu',
#   'enlem': '40.735828',
#   'boylam': '31.606110',
#   'ulke': 'TR'},
#  {'ID': '747712',
#   'isim': 'Edirne',
#   'enlem': '41.677189',
#   'boylam': '26.555969',
#   'ulke': 'TR'},
#  {'ID': '749780',
#   'isim': 'Canakkale',
#   'enlem': '40.145561',
#   'boylam': '26.406389',
#   'ulke': 'TR'},
#  {'ID': '304184',
#   'isim': 'Mugla',
#   'enlem': '37.218071',
#   'boylam': '28.366501',
#   'ulke': 'TR'},
#  {'ID': '738648',
#   'isim': 'Trabzon',
#   'enlem': '41.005001',
#   'boylam': '39.726940',
#   'ulke': 'TR'},
#  {'ID': '307654',
#   'isim': 'Kirikkale',
#   'enlem': '39.845280',
#   'boylam': '33.506390',
#   'ulke': 'TR'},
#  {'ID': '315368',
#   'isim': 'Erzurum',
#   'enlem': '39.908611',
#   'boylam': '41.276939',
#   'ulke': 'TR'},
#  {'ID': '323779',
#   'isim': 'Antioch',
#   'enlem': '36.206551',
#   'boylam': '36.157219',
#   'ulke': 'TR'},
#  {'ID': '737022',
#   'isim': 'Zonguldak',
#   'enlem': '41.451389',
#   'boylam': '31.793051',
#   'ulke': 'TR'},
#  {'ID': '737611',
#   'isim': 'Yenisehir',
#   'enlem': '40.264439',
#   'boylam': '29.653061',
#   'ulke': 'TR'},
#  {'ID': '741045',
#   'isim': 'Orhangazi',
#   'enlem': '40.489170',
#   'boylam': '29.308889',
#   'ulke': 'TR'},
#  {'ID': '310859',
#   'isim': 'Kahramanmaras',
#   'enlem': '37.584702',
#   'boylam': '36.926399',
#   'ulke': 'TR'},
#  {'ID': '748893',
#   'isim': 'Corlu',
#   'enlem': '41.159168',
#   'boylam': '27.799999',
#   'ulke': 'TR'},
#  {'ID': '300619',
#   'isim': 'Sivas',
#   'enlem': '39.748329',
#   'boylam': '37.016109',
#   'ulke': 'TR'},
#  {'ID': '749274',
#   'isim': 'Cerkezkoy',
#   'enlem': '41.285000',
#   'boylam': '28.000280',
#   'ulke': 'TR'},
#  {'ID': '744926',
#   'isim': 'Kadikoy',
#   'enlem': '40.620152',
#   'boylam': '29.225361',
#   'ulke': 'TR'},
#  {'ID': '315808',
#   'isim': 'Elazig',
#   'enlem': '38.674309',
#   'boylam': '39.223209',
#   'ulke': 'TR'},
#  {'ID': '321836',
#   'isim': 'Batman',
#   'enlem': '37.887379',
#   'boylam': '41.132210',
#   'ulke': 'TR'},
#  {'ID': '746666',
#   'isim': 'Geulzuk',
#   'enlem': '40.716671',
#   'boylam': '29.828609',
#   'ulke': 'TR'},
#  {'ID': '324496',
#   'isim': 'Aksaray',
#   'enlem': '38.372551',
#   'boylam': '34.025372',
#   'ulke': 'TR'},
#  {'ID': '318755',
#   'isim': 'Cesme',
#   'enlem': '38.322781',
#   'boylam': '26.306391',
#   'ulke': 'TR'},
#  {'ID': '314967',
#   'isim': 'Fethiye',
#   'enlem': '36.621670',
#   'boylam': '29.116390',
#   'ulke': 'TR'},
#  {'ID': '739634',
#   'isim': 'Silivri',
#   'enlem': '41.080219',
#   'boylam': '28.226049',
#   'ulke': 'TR'},
#  {'ID': '752015',
#   'isim': 'Amasya',
#   'enlem': '40.653332',
#   'boylam': '35.833061',
#   'ulke': 'TR'},
#  {'ID': '746574',
#   'isim': 'Gonen',
#   'enlem': '40.104900',
#   'boylam': '27.653990',
#   'ulke': 'TR'},
#  {'ID': '315373',
#   'isim': 'Erzincan',
#   'enlem': '39.752220',
#   'boylam': '39.492779',
#   'ulke': 'TR'},
#  {'ID': '307864',
#   'isim': 'Kilis',
#   'enlem': '36.716110',
#   'boylam': '37.115002',
#   'ulke': 'TR'},
#  {'ID': '741100',
#   'isim': 'Ordu',
#   'enlem': '40.984718',
#   'boylam': '37.878891',
#   'ulke': 'TR'},
#  {'ID': '743439',
#   'isim': 'Kesan',
#   'enlem': '40.855831',
#   'boylam': '26.630280',
#   'ulke': 'TR'},
#  {'ID': '316541',
#   'isim': 'Diyarbakir',
#   'enlem': '37.915829',
#   'boylam': '40.218891',
#   'ulke': 'TR'},
#  {'ID': '309527',
#   'isim': 'Karaman',
#   'enlem': '37.181110',
#   'boylam': '33.215000',
#   'ulke': 'TR'},
#  {'ID': '750605',
#   'isim': 'Biga',
#   'enlem': '40.228062',
#   'boylam': '27.242220',
#   'ulke': 'TR'},
#  {'ID': '744562',
#   'isim': 'Karabuk',
#   'enlem': '41.204880',
#   'boylam': '32.627682',
#   'ulke': 'TR'},
#  {'ID': '751817',
#   'isim': 'Artvin',
#   'enlem': '41.182220',
#   'boylam': '41.819439',
#   'ulke': 'TR'},
#  {'ID': '315498',
#   'isim': 'Eregli',
#   'enlem': '37.513329',
#   'boylam': '34.046719',
#   'ulke': 'TR'},
#  {'ID': '317851',
#   'isim': 'Cumaovasi',
#   'enlem': '38.249630',
#   'boylam': '27.134291',
#   'ulke': 'TR'},
#  {'ID': '298299',
#   'isim': 'Usak',
#   'enlem': '38.673512',
#   'boylam': '29.405800',
#   'ulke': 'TR'},
#  {'ID': '300399',
#   'isim': 'Soeke',
#   'enlem': '37.748199',
#   'boylam': '27.406139',
#   'ulke': 'TR'},
#  {'ID': '743166',
#   'isim': 'Kirklareli',
#   'enlem': '41.735081',
#   'boylam': '27.225210',
#   'ulke': 'TR'},
#  {'ID': '747764',
#   'isim': 'Duzce',
#   'enlem': '40.838890',
#   'boylam': '31.163891',
#   'ulke': 'TR'},
#  {'ID': '321082',
#   'isim': 'Bingol',
#   'enlem': '38.884720',
#   'boylam': '40.493889',
#   'ulke': 'TR'},
#  {'ID': '751371',
#   'isim': 'Babaeski',
#   'enlem': '41.432499',
#   'boylam': '27.093060',
#   'ulke': 'TR'},
#  {'ID': '303873',
#   'isim': 'Nazilli',
#   'enlem': '37.916309',
#   'boylam': '28.322250',
#   'ulke': 'TR'},
#  {'ID': '299817',
#   'isim': 'Tarsus',
#   'enlem': '36.918758',
#   'boylam': '34.878399',
#   'ulke': 'TR'},
#  {'ID': '741855',
#   'isim': 'Luleburgaz',
#   'enlem': '41.403851',
#   'boylam': '27.359180',
#   'ulke': 'TR'},
#  {'ID': '321426',
#   'isim': 'Bergama',
#   'enlem': '39.120739',
#   'boylam': '27.180519',
#   'ulke': 'TR'},
#  {'ID': '296562',
#   'isim': 'Yozgat',
#   'enlem': '39.820000',
#   'boylam': '34.804440',
#   'ulke': 'TR'},
#  {'ID': '748879',
#   'isim': 'Corum',
#   'enlem': '40.548889',
#   'boylam': '34.953331',
#   'ulke': 'TR'},
#  {'ID': '740483',
#   'isim': 'Rize',
#   'enlem': '41.020828',
#   'boylam': '40.521938',
#   'ulke': 'TR'},
#  {'ID': '738025',
#   'isim': 'Yalova',
#   'enlem': '40.655022',
#   'boylam': '29.276930',
#   'ulke': 'TR'},
#  {'ID': '740430',
#   'isim': 'Safranbolu',
#   'enlem': '41.250832',
#   'boylam': '32.694172',
#   'ulke': 'TR'},
#  {'ID': '318137',
#   'isim': 'Hakkari',
#   'enlem': '37.574440',
#   'boylam': '43.740829',
#   'ulke': 'TR'},
#  {'ID': '320533',
#   'isim': 'Bucak',
#   'enlem': '37.459171',
#   'boylam': '30.594999',
#   'ulke': 'TR'},
#  {'ID': '298846',
#   'isim': 'Tunceli',
#   'enlem': '39.108292',
#   'boylam': '39.547112',
#   'ulke': 'TR'},
#  {'ID': '749748',
#   'isim': 'Khanjarah',
#   'enlem': '40.599949',
#   'boylam': '33.615299',
#   'ulke': 'TR'},
#  {'ID': '746958',
#   'isim': 'Gemlik',
#   'enlem': '40.430939',
#   'boylam': '29.159691',
#   'ulke': 'TR'},
#  {'ID': '738349',
#   'isim': 'Unieh',
#   'enlem': '41.131390',
#   'boylam': '37.282501',
#   'ulke': 'TR'},
#  {'ID': '738803',
#   'isim': 'Terme',
#   'enlem': '41.209171',
#   'boylam': '36.973888',
#   'ulke': 'TR'},
#  {'ID': '745697',
#   'isim': 'Hayrabolu',
#   'enlem': '41.213112',
#   'boylam': '27.106880',
#   'ulke': 'TR'},
#  {'ID': '747323',
#   'isim': 'Esenyurt',
#   'enlem': '41.033329',
#   'boylam': '28.675280',
#   'ulke': 'TR'},
#  {'ID': '741304',
#   'isim': 'Niksar',
#   'enlem': '40.591671',
#   'boylam': '36.951672',
#   'ulke': 'TR'},
#  {'ID': '303831',
#   'isim': 'Nevsehir',
#   'enlem': '38.625000',
#   'boylam': '34.712219',
#   'ulke': 'TR'},
#  {'ID': '310892',
#   'isim': 'Kadirli',
#   'enlem': '37.373890',
#   'boylam': '36.096111',
#   'ulke': 'TR'},
#  {'ID': '318675',
#   'isim': 'Ceyhan',
#   'enlem': '37.024719',
#   'boylam': '35.817501',
#   'ulke': 'TR'},
#  {'ID': '300822',
#   'isim': 'Siirt',
#   'enlem': '37.932621',
#   'boylam': '41.940250',
#   'ulke': 'TR'},
#  {'ID': '741160',
#   'isim': 'Oltu',
#   'enlem': '40.549831',
#   'boylam': '42.001259',
#   'ulke': 'TR'},
#  {'ID': '298117',
#   'isim': 'Van',
#   'enlem': '38.492390',
#   'boylam': '43.383110',
#   'ulke': 'TR'},
#  {'ID': '318766',
#   'isim': 'Cermik',
#   'enlem': '38.136131',
#   'boylam': '39.449291',
#   'ulke': 'TR'},
#  {'ID': '315468',
#   'isim': 'Ergani',
#   'enlem': '38.265331',
#   'boylam': '39.762119',
#   'ulke': 'TR'},
#  {'ID': '746565',
#   'isim': 'Gorele',
#   'enlem': '41.030830',
#   'boylam': '39.003059',
#   'ulke': 'TR'},
#  {'ID': '751335',
#   'isim': 'Bafra',
#   'enlem': '41.567780',
#   'boylam': '35.906940',
#   'ulke': 'TR'},
#  {'ID': '746425',
#   'isim': 'Gumushkhane',
#   'enlem': '40.460281',
#   'boylam': '39.481392',
#   'ulke': 'TR'},
#  {'ID': '745169',
#   'isim': 'Inegeul',
#   'enlem': '40.078060',
#   'boylam': '29.513330',
#   'ulke': 'TR'},
#  {'ID': '307515',
#   'isim': 'Kirsehir',
#   'enlem': '39.145828',
#   'boylam': '34.163891',
#   'ulke': 'TR'},
#  {'ID': '751952',
#   'isim': 'Ardahan',
#   'enlem': '41.108711',
#   'boylam': '42.702221',
#   'ulke': 'TR'},
#  {'ID': '744168',
#   'isim': 'Karamursel',
#   'enlem': '40.691441',
#   'boylam': '29.615681',
#   'ulke': 'TR'},
#  {'ID': '321062',
#   'isim': 'Birecik',
#   'enlem': '37.029442',
#   'boylam': '37.990280',
#   'ulke': 'TR'},
#  {'ID': '745026',
#   'isim': 'Iznik',
#   'enlem': '40.428612',
#   'boylam': '29.721109',
#   'ulke': 'TR'},
#  {'ID': '741771',
#   'isim': 'Malkara',
#   'enlem': '40.889999',
#   'boylam': '26.901110',
#   'ulke': 'TR'},
#  {'ID': '300640',
#   'isim': 'Sirnak',
#   'enlem': '37.522781',
#   'boylam': '42.459438',
#   'ulke': 'TR'},
#  {'ID': '741609',
#   'isim': 'Merzifon',
#   'enlem': '40.873329',
#   'boylam': '35.463058',
#   'ulke': 'TR'},
#  {'ID': '310855',
#   'isim': 'Kahta',
#   'enlem': '37.785519',
#   'boylam': '38.623699',
#   'ulke': 'TR'},
#  {'ID': '739600',
#   'isim': 'Sinop',
#   'enlem': '42.026829',
#   'boylam': '35.162521',
#   'ulke': 'TR'},
#  {'ID': '298806',
#   'isim': 'Turgutlu',
#   'enlem': '38.495331',
#   'boylam': '27.699699',
#   'ulke': 'TR'},
#  {'ID': '304854',
#   'isim': 'Manavgat',
#   'enlem': '36.786671',
#   'boylam': '31.443060',
#   'ulke': 'TR'},
#  {'ID': '741487',
#   'isim': 'Mudanya',
#   'enlem': '40.375278',
#   'boylam': '28.882219',
#   'ulke': 'TR'},
#  {'ID': '310641',
#   'isim': 'Kaman',
#   'enlem': '39.357498',
#   'boylam': '33.723888',
#   'ulke': 'TR'},
#  {'ID': '324106',
#   'isim': 'Aliaga',
#   'enlem': '38.799751',
#   'boylam': '26.972031',
#   'ulke': 'TR'},
#  {'ID': '302043',
#   'isim': 'Salihli',
#   'enlem': '38.482578',
#   'boylam': '28.147739',
#   'ulke': 'TR'},
#  {'ID': '739236',
#   'isim': 'Sungurlu',
#   'enlem': '40.167500',
#   'boylam': '34.373890',
#   'ulke': 'TR'},
#  {'ID': '304382',
#   'isim': 'Midyat',
#   'enlem': '37.424702',
#   'boylam': '41.339340',
#   'ulke': 'TR'},
#  {'ID': '301101',
#   'isim': 'Serik',
#   'enlem': '36.916939',
#   'boylam': '31.098890',
#   'ulke': 'TR'},
#  {'ID': '305532',
#   'isim': 'Kurtalan',
#   'enlem': '37.927170',
#   'boylam': '41.702820',
#   'ulke': 'TR'},
#  {'ID': '747155',
#   'isim': 'Fatsa',
#   'enlem': '41.027779',
#   'boylam': '37.501389',
#   'ulke': 'TR'},
#  {'ID': '300614',
#   'isim': 'Siverek',
#   'enlem': '37.755020',
#   'boylam': '39.316669',
#   'ulke': 'TR'},
#  {'ID': '302724',
#   'isim': 'Pertek',
#   'enlem': '38.866329',
#   'boylam': '39.326839',
#   'ulke': 'TR'},
#  {'ID': '300273',
#   'isim': 'Suhut',
#   'enlem': '38.531109',
#   'boylam': '30.545830',
#   'ulke': 'TR'},
#  {'ID': '316795',
#   'isim': 'Develi',
#   'enlem': '38.390560',
#   'boylam': '35.492222',
#   'ulke': 'TR'},
#  {'ID': '300352',
#   'isim': 'Sorgun',
#   'enlem': '39.810120',
#   'boylam': '35.185959',
#   'ulke': 'TR'},
#  {'ID': '750938',
#   'isim': 'Bayburt',
#   'enlem': '40.258888',
#   'boylam': '40.227779',
#   'ulke': 'TR'},
#  {'ID': '308133',
#   'isim': 'Kepsut',
#   'enlem': '39.688889',
#   'boylam': '28.152220',
#   'ulke': 'TR'},
#  {'ID': '305359',
#   'isim': 'Kusadasi',
#   'enlem': '37.855621',
#   'boylam': '27.256599',
#   'ulke': 'TR'},
#  {'ID': '305810',
#   'isim': 'Kula',
#   'enlem': '38.547260',
#   'boylam': '28.649759',
#   'ulke': 'TR'},
#  {'ID': '749795',
#   'isim': 'Can',
#   'enlem': '40.033279',
#   'boylam': '27.052361',
#   'ulke': 'TR'},
#  {'ID': '751077',
#   'isim': 'Bandirma',
#   'enlem': '40.352219',
#   'boylam': '27.976669',
#   'ulke': 'TR'},
#  {'ID': '321191',
#   'isim': 'Beysehir',
#   'enlem': '37.677349',
#   'boylam': '31.724581',
#   'ulke': 'TR'},
#  {'ID': '308224',
#   'isim': 'Kemalpasa',
#   'enlem': '38.426208',
#   'boylam': '27.417311',
#   'ulke': 'TR'},
#  {'ID': '749644',
#   'isim': 'Catalca',
#   'enlem': '41.143242',
#   'boylam': '28.461540',
#   'ulke': 'TR'},
#  {'ID': '298316',
#   'isim': 'Urla',
#   'enlem': '38.322922',
#   'boylam': '26.764030',
#   'ulke': 'TR'},
#  {'ID': '318253',
#   'isim': 'Cizre',
#   'enlem': '37.327221',
#   'boylam': '42.190281',
#   'ulke': 'TR'},
#  {'ID': '738251',
#   'isim': 'Uzun Keupru',
#   'enlem': '41.265980',
#   'boylam': '26.688499',
#   'ulke': 'TR'},
#  {'ID': '320871',
#   'isim': 'Bor',
#   'enlem': '37.890560',
#   'boylam': '34.558891',
#   'ulke': 'TR'},
#  {'ID': '324698',
#   'isim': 'Akhisar',
#   'enlem': '38.918522',
#   'boylam': '27.840059',
#   'ulke': 'TR'},
#  {'ID': '304355',
#   'isim': 'Milas',
#   'enlem': '37.316391',
#   'boylam': '27.783890',
#   'ulke': 'TR'},
#  {'ID': '311704',
#   'isim': 'Idil',
#   'enlem': '37.341141',
#   'boylam': '41.889500',
#   'ulke': 'TR'},
#  {'ID': '314188',
#   'isim': 'Goksun',
#   'enlem': '38.020962',
#   'boylam': '36.497299',
#   'ulke': 'TR'},
#  {'ID': '750392',
#   'isim': 'Bozkurt',
#   'enlem': '41.957691',
#   'boylam': '34.010860',
#   'ulke': 'TR'},
#  {'ID': '325330',
#   'isim': 'Adiyaman',
#   'enlem': '37.764408',
#   'boylam': '38.276291',
#   'ulke': 'TR'},
#  {'ID': '322830',
#   'isim': 'Aydin',
#   'enlem': '37.845009',
#   'boylam': '27.839630',
#   'ulke': 'TR'},
#  {'ID': '738668',
#   'isim': 'Torul',
#   'enlem': '40.558048',
#   'boylam': '39.293598',
#   'ulke': 'TR'},
#  {'ID': '324490',
#   'isim': 'Aksehir',
#   'enlem': '38.357498',
#   'boylam': '31.416389',
#   'ulke': 'TR'},
#  {'ID': '322673',
#   'isim': 'Ayvalik',
#   'enlem': '39.319050',
#   'boylam': '26.695400',
#   'ulke': 'TR'},
#  {'ID': '296134',
#   'isim': 'Yunak',
#   'enlem': '38.814178',
#   'boylam': '31.732241',
#   'ulke': 'TR'},
#  {'ID': '311665',
#   'isim': 'Igdir',
#   'enlem': '39.923710',
#   'boylam': '44.044998',
#   'ulke': 'TR'},
#  {'ID': '744110',
#   'isim': 'Karapurcek',
#   'enlem': '40.641941',
#   'boylam': '30.539440',
#   'ulke': 'TR'},
#  {'ID': '304612',
#   'isim': 'Menemen',
#   'enlem': '38.607540',
#   'boylam': '27.069380',
#   'ulke': 'TR'},
#  {'ID': '321136',
#   'isim': 'Bigadic',
#   'enlem': '39.392502',
#   'boylam': '28.131109',
#   'ulke': 'TR'},
#  {'ID': '322965',
#   'isim': 'Avanos',
#   'enlem': '38.715000',
#   'boylam': '34.846668',
#   'ulke': 'TR'},
#  {'ID': '311869',
#   'isim': 'Hozat',
#   'enlem': '39.108292',
#   'boylam': '39.221272',
#   'ulke': 'TR'},
#  {'ID': '315795',
#   'isim': 'Elbistan',
#   'enlem': '38.205910',
#   'boylam': '37.198299',
#   'ulke': 'TR'},
#  {'ID': '325336',
#   'isim': 'Adilcevaz',
#   'enlem': '38.803890',
#   'boylam': '42.734219',
#   'ulke': 'TR'},
#  {'ID': '316102',
#   'isim': 'Dursunbey',
#   'enlem': '39.585960',
#   'boylam': '28.625681',
#   'ulke': 'TR'},
#  {'ID': '751324',
#   'isim': 'Bagcilar',
#   'enlem': '41.039028',
#   'boylam': '28.856710',
#   'ulke': 'TR'},
#  {'ID': '299445',
#   'isim': 'Tekirova',
#   'enlem': '36.501701',
#   'boylam': '30.527229',
#   'ulke': 'TR'},
#  {'ID': '743633',
#   'isim': 'Kaynarca',
#   'enlem': '41.030830',
#   'boylam': '30.307501',
#   'ulke': 'TR'},
#  {'ID': '298451',
#   'isim': 'Uluborlu',
#   'enlem': '38.077782',
#   'boylam': '30.457220',
#   'ulke': 'TR'},
#  {'ID': '745714',
#   'isim': 'Havza',
#   'enlem': '40.970558',
#   'boylam': '35.662220',
#   'ulke': 'TR'},
#  {'ID': '315530',
#   'isim': 'Ercis',
#   'enlem': '39.028690',
#   'boylam': '43.358639',
#   'ulke': 'TR'},
#  {'ID': '306112',
#   'isim': 'Kozan',
#   'enlem': '37.455170',
#   'boylam': '35.815731',
#   'ulke': 'TR'},
#  {'ID': '299582',
#   'isim': 'Tatvan',
#   'enlem': '38.506672',
#   'boylam': '42.281670',
#   'ulke': 'TR'},
#  {'ID': '317543',
#   'isim': 'Datca',
#   'enlem': '36.737782',
#   'boylam': '27.684170',
#   'ulke': 'TR'},
#  {'ID': '317681',
#   'isim': 'Dalyan',
#   'enlem': '36.834290',
#   'boylam': '28.644600',
#   'ulke': 'TR'},
#  {'ID': '739847',
#   'isim': 'Selim',
#   'enlem': '40.463261',
#   'boylam': '42.783951',
#   'ulke': 'TR'},
#  {'ID': '744873',
#   'isim': 'Kagizman',
#   'enlem': '40.156689',
#   'boylam': '43.134239',
#   'ulke': 'TR'},
#  {'ID': '744716',
#   'isim': 'Kandira',
#   'enlem': '41.073601',
#   'boylam': '30.174601',
#   'ulke': 'TR'},
#  {'ID': '314716',
#   'isim': 'Gediz',
#   'enlem': '39.041672',
#   'boylam': '29.410000',
#   'ulke': 'TR'},
#  {'ID': '296173',
#   'isim': 'Yuksekova',
#   'enlem': '37.573620',
#   'boylam': '44.287159',
#   'ulke': 'TR'},
#  {'ID': '751950',
#   'isim': 'Ardanuc',
#   'enlem': '41.127380',
#   'boylam': '42.062920',
#   'ulke': 'TR'},
#  {'ID': '745175',
#   'isim': 'Inebolu',
#   'enlem': '41.974720',
#   'boylam': '33.760830',
#   'ulke': 'TR'},
#  {'ID': '745148',
#   'isim': 'Ipsala',
#   'enlem': '40.921150',
#   'boylam': '26.382730',
#   'ulke': 'TR'},
#  {'ID': '744093',
#   'isim': 'Karasu',
#   'enlem': '41.070961',
#   'boylam': '30.785431',
#   'ulke': 'TR'},
#  {'ID': '303798',
#   'isim': 'Nizip',
#   'enlem': '37.009720',
#   'boylam': '37.794170',
#   'ulke': 'TR'},
#  {'ID': '302525',
#   'isim': 'Polatli',
#   'enlem': '39.577160',
#   'boylam': '32.141319',
#   'ulke': 'TR'},
#  {'ID': '309663',
#   'isim': 'Karakocan',
#   'enlem': '38.955830',
#   'boylam': '40.038609',
#   'ulke': 'TR'},
#  {'ID': '325304',
#   'isim': 'Afsin',
#   'enlem': '38.247688',
#   'boylam': '36.913990',
#   'ulke': 'TR'},
#  {'ID': '746821',
#   'isim': 'Gokcebey',
#   'enlem': '41.305828',
#   'boylam': '32.142342',
#   'ulke': 'TR'},
#  {'ID': '304734',
#   'isim': 'Mazidagi',
#   'enlem': '37.477501',
#   'boylam': '40.488060',
#   'ulke': 'TR'},
#  {'ID': '740230',
#   'isim': 'Sapanca',
#   'enlem': '40.691410',
#   'boylam': '30.267380',
#   'ulke': 'TR'},
#  {'ID': '320581',
#   'isim': 'Bozova',
#   'enlem': '37.362499',
#   'boylam': '38.526669',
#   'ulke': 'TR'},
#  {'ID': '298033',
#   'isim': 'Viransehir',
#   'enlem': '37.235279',
#   'boylam': '39.763062',
#   'ulke': 'TR'},
#  {'ID': '739816',
#   'isim': 'Senkaya',
#   'enlem': '40.561939',
#   'boylam': '42.346939',
#   'ulke': 'TR'},
#  {'ID': '310554',
#   'isim': 'Kangal',
#   'enlem': '39.233540',
#   'boylam': '37.391109',
#   'ulke': 'TR'},
#  {'ID': '313669',
#   'isim': 'Gulnar',
#   'enlem': '36.341480',
#   'boylam': '33.399212',
#   'ulke': 'TR'},
#  {'ID': '308776',
#   'isim': 'Kavaklidere',
#   'enlem': '37.444630',
#   'boylam': '28.362761',
#   'ulke': 'TR'},
#  {'ID': '752288',
#   'isim': 'Akyazi',
#   'enlem': '40.685001',
#   'boylam': '30.622219',
#   'ulke': 'TR'},
#  {'ID': '321929',
#   'isim': 'Baskil',
#   'enlem': '38.567909',
#   'boylam': '38.823818',
#   'ulke': 'TR'},
#  {'ID': '745527',
#   'isim': 'Horasan',
#   'enlem': '40.045830',
#   'boylam': '42.172779',
#   'ulke': 'TR'},
#  {'ID': '315639',
#   'isim': 'Emet',
#   'enlem': '39.342999',
#   'boylam': '29.258471',
#   'ulke': 'TR'},
#  {'ID': '315697',
#   'isim': 'Elmali',
#   'enlem': '36.735828',
#   'boylam': '29.917749',
#   'ulke': 'TR'},
#  {'ID': '314903',
#   'isim': 'Foca',
#   'enlem': '38.670300',
#   'boylam': '26.756559',
#   'ulke': 'TR'},
#  {'ID': '320621',
#   'isim': 'Bozkir',
#   'enlem': '37.189629',
#   'boylam': '32.247360',
#   'ulke': 'TR'},
#  {'ID': '741737',
#   'isim': 'Manyas',
#   'enlem': '40.046391',
#   'boylam': '27.969999',
#   'ulke': 'TR'},
#  {'ID': '316411',
#   'isim': 'Dogubayazit',
#   'enlem': '39.546940',
#   'boylam': '44.084171',
#   'ulke': 'TR'},
#  {'ID': '749163',
#   'isim': 'Ciftlikkoy',
#   'enlem': '40.660278',
#   'boylam': '29.323610',
#   'ulke': 'TR'},
#  {'ID': '302355',
#   'isim': 'Reyhanli',
#   'enlem': '36.269169',
#   'boylam': '36.567219',
#   'ulke': 'TR'},
#  {'ID': '745047',
#   'isim': 'Ispir',
#   'enlem': '40.482868',
#   'boylam': '40.995571',
#   'ulke': 'TR'},
#  {'ID': '297789',
#   'isim': 'Yalvac',
#   'enlem': '38.295559',
#   'boylam': '31.177780',
#   'ulke': 'TR'},
#  {'ID': '739107',
#   'isim': 'Tarakli',
#   'enlem': '40.396938',
#   'boylam': '30.492781',
#   'ulke': 'TR'},
#  {'ID': '738154',
#   'isim': 'Vize',
#   'enlem': '41.572498',
#   'boylam': '27.765829',
#   'ulke': 'TR'},
#  {'ID': '300195',
#   'isim': 'Sultanhisar',
#   'enlem': '37.889721',
#   'boylam': '28.157499',
#   'ulke': 'TR'},
#  {'ID': '316440',
#   'isim': 'Dogansehir',
#   'enlem': '38.091942',
#   'boylam': '37.878891',
#   'ulke': 'TR'},
#  {'ID': '325426',
#   'isim': 'Acipayam',
#   'enlem': '37.423851',
#   'boylam': '29.349409',
#   'ulke': 'TR'},
#  {'ID': '303648',
#   'isim': 'Oguz',
#   'enlem': '37.177631',
#   'boylam': '40.954369',
#   'ulke': 'TR'},
#  {'ID': '324944',
#   'isim': 'Akcakale',
#   'enlem': '36.711109',
#   'boylam': '38.947498',
#   'ulke': 'TR'},
#  {'ID': '737054',
#   'isim': 'Zile',
#   'enlem': '40.303059',
#   'boylam': '35.886391',
#   'ulke': 'TR'},
#  {'ID': '303409',
#   'isim': 'Orhaneli',
#   'enlem': '39.903332',
#   'boylam': '28.990561',
#   'ulke': 'TR'},
#  {'ID': '741850',
#   'isim': 'Macka',
#   'enlem': '40.818611',
#   'boylam': '39.613609',
#   'ulke': 'TR'},
#  {'ID': '312862',
#   'isim': 'Halfeti',
#   'enlem': '37.247292',
#   'boylam': '37.868961',
#   'ulke': 'TR'},
#  {'ID': '306207',
#   'isim': 'Kovancilar',
#   'enlem': '38.721390',
#   'boylam': '39.868061',
#   'ulke': 'TR'},
#  {'ID': '301350',
#   'isim': 'Seferihisar',
#   'enlem': '38.196861',
#   'boylam': '26.839020',
#   'ulke': 'TR'},
#  {'ID': '306474',
#   'isim': 'Korkuteli',
#   'enlem': '37.064980',
#   'boylam': '30.195650',
#   'ulke': 'TR'},
#  {'ID': '300797',
#   'isim': 'Silopi',
#   'enlem': '37.249722',
#   'boylam': '42.469440',
#   'ulke': 'TR'},
#  {'ID': '740729',
#   'isim': 'Pamukova',
#   'enlem': '40.508099',
#   'boylam': '30.167320',
#   'ulke': 'TR'},
#  {'ID': '313995',
#   'isim': 'Armutova',
#   'enlem': '39.390160',
#   'boylam': '26.841270',
#   'ulke': 'TR'},
#  {'ID': '308948',
#   'isim': 'Kas',
#   'enlem': '36.201759',
#   'boylam': '29.637659',
#   'ulke': 'TR'},
#  {'ID': '745719',
#   'isim': 'Havsa',
#   'enlem': '41.548981',
#   'boylam': '26.822069',
#   'ulke': 'TR'},
#  {'ID': '308389',
#   'isim': 'Keban',
#   'enlem': '38.797779',
#   'boylam': '38.733608',
#   'ulke': 'TR'},
#  {'ID': '314923',
#   'isim': 'Finike',
#   'enlem': '36.294998',
#   'boylam': '30.140560',
#   'ulke': 'TR'},
#  {'ID': '739636',
#   'isim': 'Sile',
#   'enlem': '41.175400',
#   'boylam': '29.613331',
#   'ulke': 'TR'},
#  {'ID': '305089',
#   'isim': 'Lice',
#   'enlem': '38.459171',
#   'boylam': '40.647499',
#   'ulke': 'TR'},
#  {'ID': '308230',
#   'isim': 'Kemaliye',
#   'enlem': '39.262878',
#   'boylam': '38.496738',
#   'ulke': 'TR'},
#  {'ID': '745344',
#   'isim': 'Ilgaz',
#   'enlem': '40.925110',
#   'boylam': '33.625858',
#   'ulke': 'TR'},
#  {'ID': '323828',
#   'isim': 'Anamur',
#   'enlem': '36.075081',
#   'boylam': '32.836910',
#   'ulke': 'TR'},
#  {'ID': '321580',
#   'isim': 'Belek',
#   'enlem': '36.862782',
#   'boylam': '31.055559',
#   'ulke': 'TR'},
#  {'ID': '298088',
#   'isim': 'Varto',
#   'enlem': '39.173210',
#   'boylam': '41.455929',
#   'ulke': 'TR'},
#  {'ID': '302482',
#   'isim': 'Pozanti',
#   'enlem': '37.427780',
#   'boylam': '34.871670',
#   'ulke': 'TR'},
#  {'ID': '321360',
#   'isim': 'Besiri',
#   'enlem': '37.918381',
#   'boylam': '41.292400',
#   'ulke': 'TR'},
#  {'ID': '303872',
#   'isim': 'Nazimiye',
#   'enlem': '39.179859',
#   'boylam': '39.828430',
#   'ulke': 'TR'},
#  {'ID': '312663',
#   'isim': 'Hani',
#   'enlem': '38.416672',
#   'boylam': '40.400002',
#   'ulke': 'TR'},
#  {'ID': '745260',
#   'isim': 'Gokceada',
#   'enlem': '40.201069',
#   'boylam': '25.909019',
#   'ulke': 'TR'},
#  {'ID': '740088',
#   'isim': 'Sarikamis',
#   'enlem': '40.338058',
#   'boylam': '42.573059',
#   'ulke': 'TR'},
#  {'ID': '301483',
#   'isim': 'Sason',
#   'enlem': '38.336441',
#   'boylam': '41.413021',
#   'ulke': 'TR'},
#  {'ID': '296832',
#   'isim': 'Yesilli',
#   'enlem': '37.340500',
#   'boylam': '40.825581',
#   'ulke': 'TR'},
#  {'ID': '296852',
#   'isim': 'Erzin',
#   'enlem': '36.955891',
#   'boylam': '36.200001',
#   'ulke': 'TR'},
#  {'ID': '296895',
#   'isim': 'Yerkoy',
#   'enlem': '39.638062',
#   'boylam': '34.467220',
#   'ulke': 'TR'},
#  {'ID': '297090',
#   'isim': 'Didim',
#   'enlem': '37.375561',
#   'boylam': '27.267780',
#   'ulke': 'TR'},
#  {'ID': '297564',
#   'isim': 'Yatagan',
#   'enlem': '37.340260',
#   'boylam': '28.142790',
#   'ulke': 'TR'},
#  {'ID': '297917',
#   'isim': 'Yahyali',
#   'enlem': '38.102280',
#   'boylam': '35.357040',
#   'ulke': 'TR'},
#  {'ID': '298230',
#   'isim': 'Cimin',
#   'enlem': '39.710110',
#   'boylam': '39.702129',
#   'ulke': 'TR'},
#  {'ID': '298326',
#   'isim': 'Urgub',
#   'enlem': '38.629601',
#   'boylam': '34.911980',
#   'ulke': 'TR'},
#  {'ID': '298935',
#   'isim': 'Torbali',
#   'enlem': '38.151901',
#   'boylam': '27.362230',
#   'ulke': 'TR'},
#  {'ID': '299137',
#   'isim': 'Tire',
#   'enlem': '38.088772',
#   'boylam': '27.735081',
#   'ulke': 'TR'},
#  {'ID': '299545',
#   'isim': 'Tavsanli',
#   'enlem': '39.542370',
#   'boylam': '29.498659',
#   'ulke': 'TR'},
#  {'ID': '299900',
#   'isim': 'Talas',
#   'enlem': '38.690800',
#   'boylam': '35.553799',
#   'ulke': 'TR'},
#  {'ID': '300058',
#   'isim': 'Susurluk',
#   'enlem': '39.913609',
#   'boylam': '28.157780',
#   'ulke': 'TR'},
#  {'ID': '300075',
#   'isim': 'Suruc',
#   'enlem': '36.976139',
#   'boylam': '38.424950',
#   'ulke': 'TR'},
#  {'ID': '300371',
#   'isim': 'Soma',
#   'enlem': '39.185539',
#   'boylam': '27.609449',
#   'ulke': 'TR'},
#  {'ID': '300377',
#   'isim': 'Solhan',
#   'enlem': '38.963379',
#   'boylam': '41.029308',
#   'ulke': 'TR'},
#  {'ID': '300791',
#   'isim': 'Simav',
#   'enlem': '39.088200',
#   'boylam': '28.977671',
#   'ulke': 'TR'},
#  {'ID': '300796',
#   'isim': 'Silvan',
#   'enlem': '38.141941',
#   'boylam': '41.008060',
#   'ulke': 'TR'},
#  {'ID': '300808',
#   'isim': 'Silifke',
#   'enlem': '36.377781',
#   'boylam': '33.934441',
#   'ulke': 'TR'},
#  {'ID': '301010',
#   'isim': 'Seydisehir',
#   'enlem': '37.419258',
#   'boylam': '31.845270',
#   'ulke': 'TR'},
#  {'ID': '301116',
#   'isim': 'Sereflikochisar',
#   'enlem': '38.939251',
#   'boylam': '33.538601',
#   'ulke': 'TR'},
#  {'ID': '301172',
#   'isim': 'Senirkent',
#   'enlem': '38.104439',
#   'boylam': '30.548611',
#   'ulke': 'TR'},
#  {'ID': '301209',
#   'isim': 'Semdinli',
#   'enlem': '37.305141',
#   'boylam': '44.574200',
#   'ulke': 'TR'},
#  {'ID': '301256',
#   'isim': 'Selcuk',
#   'enlem': '37.951370',
#   'boylam': '27.368490',
#   'ulke': 'TR'},
#  {'ID': '301537',
#   'isim': 'Sarkisla',
#   'enlem': '39.351860',
#   'boylam': '36.409760',
#   'ulke': 'TR'},
#  {'ID': '301539',
#   'isim': 'Sarkikaraagac',
#   'enlem': '38.079441',
#   'boylam': '31.366390',
#   'ulke': 'TR'},
#  {'ID': '301827',
#   'isim': 'Saraykoy',
#   'enlem': '37.924480',
#   'boylam': '28.925159',
#   'ulke': 'TR'},
#  {'ID': '301911',
#   'isim': 'Sandikli',
#   'enlem': '38.464722',
#   'boylam': '30.269461',
#   'ulke': 'TR'},
#  {'ID': '302800',
#   'isim': 'Pazarcik',
#   'enlem': '37.486851',
#   'boylam': '37.299610',
#   'ulke': 'TR'},
#  {'ID': '302819',
#   'isim': 'Patnos',
#   'enlem': '39.233608',
#   'boylam': '42.863441',
#   'ulke': 'TR'},
#  {'ID': '302824',
#   'isim': 'Pasinler',
#   'enlem': '39.980309',
#   'boylam': '41.676350',
#   'ulke': 'TR'},
#  {'ID': '303354',
#   'isim': 'Ortaca',
#   'enlem': '36.829441',
#   'boylam': '28.770830',
#   'ulke': 'TR'},
#  {'ID': '303700',
#   'isim': 'Hypaepa',
#   'enlem': '38.227798',
#   'boylam': '27.969549',
#   'ulke': 'TR'},
#  {'ID': '303750',
#   'isim': 'Nusaybin',
#   'enlem': '37.077801',
#   'boylam': '41.217800',
#   'ulke': 'TR'},
#  {'ID': '303827',
#   'isim': 'Nigde',
#   'enlem': '37.965832',
#   'boylam': '34.679352',
#   'ulke': 'TR'},
#  {'ID': '304013',
#   'isim': 'Mut',
#   'enlem': '36.643890',
#   'boylam': '33.438850',
#   'ulke': 'TR'},
#  {'ID': '304081',
#   'isim': 'Mus',
#   'enlem': '38.745251',
#   'boylam': '41.506931',
#   'ulke': 'TR'},
#  {'ID': '304196',
#   'isim': 'Mucur',
#   'enlem': '39.061470',
#   'boylam': '34.382858',
#   'ulke': 'TR'},
#  {'ID': '304531',
#   'isim': 'Mercin',
#   'enlem': '36.795261',
#   'boylam': '34.617920',
#   'ulke': 'TR'},
#  {'ID': '304782',
#   'isim': 'Marmaris',
#   'enlem': '36.855000',
#   'boylam': '28.274170',
#   'ulke': 'TR'},
#  {'ID': '304797',
#   'isim': 'Mardin',
#   'enlem': '37.313091',
#   'boylam': '40.743568',
#   'ulke': 'TR'},
#  {'ID': '304916',
#   'isim': 'Malazgirt',
#   'enlem': '39.142651',
#   'boylam': '42.540081',
#   'ulke': 'TR'},
#  {'ID': '305680',
#   'isim': 'Beykonak',
#   'enlem': '36.325729',
#   'boylam': '30.303020',
#   'ulke': 'TR'},
#  {'ID': '305742',
#   'isim': 'Kulu',
#   'enlem': '39.095139',
#   'boylam': '33.079891',
#   'ulke': 'TR'},
#  {'ID': '305750',
#   'isim': 'Kulp',
#   'enlem': '38.497219',
#   'boylam': '41.012218',
#   'ulke': 'TR'},
#  {'ID': '306041',
#   'isim': 'Kozluk',
#   'enlem': '38.193829',
#   'boylam': '41.488529',
#   'ulke': 'TR'},
#  {'ID': '307084',
#   'isim': 'Kiziltepe',
#   'enlem': '37.193329',
#   'boylam': '40.584999',
#   'ulke': 'TR'},
#  {'ID': '307211',
#   'isim': 'Serinhisar',
#   'enlem': '37.581039',
#   'boylam': '29.266390',
#   'ulke': 'TR'},
#  {'ID': '307623',
#   'isim': 'Kirkagac',
#   'enlem': '39.106380',
#   'boylam': '27.669250',
#   'ulke': 'TR'},
#  {'ID': '307657',
#   'isim': 'Kirikhan',
#   'enlem': '36.499390',
#   'boylam': '36.357552',
#   'ulke': 'TR'},
#  {'ID': '308024',
#   'isim': 'Keskin',
#   'enlem': '39.673061',
#   'boylam': '33.613609',
#   'ulke': 'TR'},
#  {'ID': '308220',
#   'isim': 'Kemer',
#   'enlem': '36.597778',
#   'boylam': '30.560560',
#   'ulke': 'TR'},
#  {'ID': '309415',
#   'isim': 'Karapinar',
#   'enlem': '37.715961',
#   'boylam': '33.550640',
#   'ulke': 'TR'},
#  {'ID': '310004',
#   'isim': 'Karacoban',
#   'enlem': '39.349190',
#   'boylam': '42.112389',
#   'ulke': 'TR'},
#  {'ID': '310907',
#   'isim': 'Kadinhani',
#   'enlem': '38.239719',
#   'boylam': '32.211391',
#   'ulke': 'TR'},
#  {'ID': '311111',
#   'isim': 'Iskenderun',
#   'enlem': '36.587181',
#   'boylam': '36.173470',
#   'ulke': 'TR'},
#  {'ID': '311314',
#   'isim': 'Incirliova',
#   'enlem': '37.852219',
#   'boylam': '27.723610',
#   'ulke': 'TR'},
#  {'ID': '311453',
#   'isim': 'Imamoglu',
#   'enlem': '37.265060',
#   'boylam': '35.657169',
#   'ulke': 'TR'},
#  {'ID': '311553',
#   'isim': 'Ilgin',
#   'enlem': '38.279171',
#   'boylam': '31.913891',
#   'ulke': 'TR'},
#  {'ID': '312024',
#   'isim': 'Hizan',
#   'enlem': '38.225719',
#   'boylam': '42.427761',
#   'ulke': 'TR'},
#  {'ID': '312114',
#   'isim': 'Hinis',
#   'enlem': '39.360600',
#   'boylam': '41.702221',
#   'ulke': 'TR'},
#  {'ID': '312134',
#   'isim': 'Hilvan',
#   'enlem': '37.586861',
#   'boylam': '38.955051',
#   'ulke': 'TR'},
#  {'ID': '312899',
#   'isim': 'Hadim',
#   'enlem': '36.987759',
#   'boylam': '32.456741',
#   'ulke': 'TR'},
#  {'ID': '313013',
#   'isim': 'Hacilar',
#   'enlem': '38.646309',
#   'boylam': '35.449371',
#   'ulke': 'TR'},
#  {'ID': '313331',
#   'isim': 'Guroymak',
#   'enlem': '38.577389',
#   'boylam': '42.028111',
#   'ulke': 'TR'},
#  {'ID': '314136',
#   'isim': 'Golbasi',
#   'enlem': '37.783611',
#   'boylam': '37.636669',
#   'ulke': 'TR'},
#  {'ID': '314648',
#   'isim': 'Genc',
#   'enlem': '38.750710',
#   'boylam': '40.560349',
#   'ulke': 'TR'},
#  {'ID': '314665',
#   'isim': 'Gemerek',
#   'enlem': '39.183418',
#   'boylam': '36.071892',
#   'ulke': 'TR'},
#  {'ID': '314812',
#   'isim': 'Gazipasa',
#   'enlem': '36.269421',
#   'boylam': '32.317921',
#   'ulke': 'TR'},
#  {'ID': '315061',
#   'isim': 'Ezine',
#   'enlem': '39.785610',
#   'boylam': '26.340830',
#   'ulke': 'TR'},
#  {'ID': '315401',
#   'isim': 'Ermenek',
#   'enlem': '36.640430',
#   'boylam': '32.891788',
#   'ulke': 'TR'},
#  {'ID': '315515',
#   'isim': 'Erdemli',
#   'enlem': '36.604980',
#   'boylam': '34.308361',
#   'ulke': 'TR'},
#  {'ID': '315621',
#   'isim': 'Emirdag',
#   'enlem': '39.019718',
#   'boylam': '31.150000',
#   'ulke': 'TR'},
#  {'ID': '315720',
#   'isim': 'Elmadag',
#   'enlem': '39.920830',
#   'boylam': '33.230831',
#   'ulke': 'TR'},
#  {'ID': '315758',
#   'isim': 'Eleskirt',
#   'enlem': '39.803329',
#   'boylam': '42.673611',
#   'ulke': 'TR'},
#  {'ID': '315905',
#   'isim': 'Egirdir',
#   'enlem': '37.874619',
#   'boylam': '30.850420',
#   'ulke': 'TR'},
#  {'ID': '316284',
#   'isim': 'Dortyol',
#   'enlem': '36.861580',
#   'boylam': '36.228851',
#   'ulke': 'TR'},
#  {'ID': '316542',
#   'isim': 'Diyadin',
#   'enlem': '39.540562',
#   'boylam': '43.671349',
#   'ulke': 'TR'},
#  {'ID': '316634',
#   'isim': 'Dinar',
#   'enlem': '38.064999',
#   'boylam': '30.165569',
#   'ulke': 'TR'},
#  {'ID': '317241',
#   'isim': 'Demirci',
#   'enlem': '39.046070',
#   'boylam': '28.658890',
#   'ulke': 'TR'},
#  {'ID': '317587',
#   'isim': 'Dargecit',
#   'enlem': '37.545448',
#   'boylam': '41.719662',
#   'ulke': 'TR'},
#  {'ID': '317588',
#   'isim': 'Darende',
#   'enlem': '38.545830',
#   'boylam': '37.505829',
#   'ulke': 'TR'},
#  {'ID': '317844',
#   'isim': 'Cumra',
#   'enlem': '37.573200',
#   'boylam': '32.774460',
#   'ulke': 'TR'},
#  {'ID': '318372',
#   'isim': 'Cine',
#   'enlem': '37.611671',
#   'boylam': '28.061390',
#   'ulke': 'TR'},
#  {'ID': '318668',
#   'isim': 'Ceylanpinar',
#   'enlem': '36.847221',
#   'boylam': '40.049999',
#   'ulke': 'TR'},
#  {'ID': '319104',
#   'isim': 'Cay',
#   'enlem': '38.591671',
#   'boylam': '31.028610',
#   'ulke': 'TR'},
#  {'ID': '320004',
#   'isim': 'Caglayancerit',
#   'enlem': '37.749592',
#   'boylam': '37.296219',
#   'ulke': 'TR'},
#  {'ID': '320369',
#   'isim': 'Burhaniye',
#   'enlem': '39.500408',
#   'boylam': '26.972691',
#   'ulke': 'TR'},
#  {'ID': '320448',
#   'isim': 'Bulanik',
#   'enlem': '39.092918',
#   'boylam': '42.270309',
#   'ulke': 'TR'},
#  {'ID': '320552',
#   'isim': 'Bozyazi',
#   'enlem': '36.108200',
#   'boylam': '32.961128',
#   'ulke': 'TR'},
#  {'ID': '320557',
#   'isim': 'Bozuyuk',
#   'enlem': '39.907780',
#   'boylam': '30.036671',
#   'ulke': 'TR'},
#  {'ID': '320879',
#   'isim': 'Bolvadin',
#   'enlem': '38.711109',
#   'boylam': '31.048611',
#   'ulke': 'TR'},
#  {'ID': '321031',
#   'isim': 'Bismil',
#   'enlem': '37.848610',
#   'boylam': '40.665829',
#   'ulke': 'TR'},
#  {'ID': '321337',
#   'isim': 'Besni',
#   'enlem': '37.692780',
#   'boylam': '37.861111',
#   'ulke': 'TR'},
#  {'ID': '321572',
#   'isim': 'Belen',
#   'enlem': '36.489109',
#   'boylam': '36.223309',
#   'ulke': 'TR'},
#  {'ID': '321786',
#   'isim': 'Bayindir',
#   'enlem': '38.217411',
#   'boylam': '27.647440',
#   'ulke': 'TR'},
#  {'ID': '322051',
#   'isim': 'Banaz',
#   'enlem': '38.737068',
#   'boylam': '29.751940',
#   'ulke': 'TR'},
#  {'ID': '322391',
#   'isim': 'Bahce',
#   'enlem': '37.197239',
#   'boylam': '36.576580',
#   'ulke': 'TR'},
#  {'ID': '323094',
#   'isim': 'Askale',
#   'enlem': '39.920830',
#   'boylam': '40.695000',
#   'ulke': 'TR'},
#  {'ID': '323777',
#   'isim': 'Antalya',
#   'enlem': '36.908119',
#   'boylam': '30.695560',
#   'ulke': 'TR'},
#  {'ID': '323786',
#   'isim': 'Ankara',
#   'enlem': '39.919868',
#   'boylam': '32.854271',
#   'ulke': 'TR'},
#  {'ID': '324172',
#   'isim': 'Alasehir',
#   'enlem': '38.350830',
#   'boylam': '28.517179',
#   'ulke': 'TR'},
#  {'ID': '324190',
#   'isim': 'Alanya',
#   'enlem': '36.543751',
#   'boylam': '31.999821',
#   'ulke': 'TR'},
#  {'ID': '324768',
#   'isim': 'Akdagmadeni',
#   'enlem': '39.660278',
#   'boylam': '35.883610',
#   'ulke': 'TR'},
#  {'ID': '325103',
#   'isim': 'Ahlat',
#   'enlem': '38.751781',
#   'boylam': '42.481350',
#   'ulke': 'TR'},
#  {'ID': '438400',
#   'isim': 'Denizciler',
#   'enlem': '36.649509',
#   'boylam': '36.229561',
#   'ulke': 'TR'},
#  {'ID': '442301',
#   'isim': 'Batikent',
#   'enlem': '39.968330',
#   'boylam': '32.730831',
#   'ulke': 'TR'},
#  {'ID': '447273',
#   'isim': 'Dalaman',
#   'enlem': '36.765911',
#   'boylam': '28.802799',
#   'ulke': 'TR'},
#  {'ID': '737071',
#   'isim': 'Zeytinburnu',
#   'enlem': '40.994411',
#   'boylam': '28.904169',
#   'ulke': 'TR'},
#  {'ID': '737421',
#   'isim': 'Yomra',
#   'enlem': '40.954109',
#   'boylam': '39.864052',
#   'ulke': 'TR'},
#  {'ID': '737961',
#   'isim': 'Korfez',
#   'enlem': '40.776669',
#   'boylam': '29.729719',
#   'ulke': 'TR'},
#  {'ID': '738064',
#   'isim': 'Yakuplu',
#   'enlem': '40.988941',
#   'boylam': '28.675819',
#   'ulke': 'TR'},
#  {'ID': '738167',
#   'isim': 'Vezirkopru',
#   'enlem': '41.143608',
#   'boylam': '35.454720',
#   'ulke': 'TR'},
#  {'ID': '738228',
#   'isim': 'Vakfikebir',
#   'enlem': '41.045830',
#   'boylam': '39.276390',
#   'ulke': 'TR'},
#  {'ID': '738377',
#   'isim': 'Umraniye',
#   'enlem': '41.016430',
#   'boylam': '29.124760',
#   'ulke': 'TR'},
#  {'ID': '738618',
#   'isim': 'Turhal',
#   'enlem': '40.387501',
#   'boylam': '36.081108',
#   'ulke': 'TR'},
#  {'ID': '738662',
#   'isim': 'Tosya',
#   'enlem': '41.015450',
#   'boylam': '34.040131',
#   'ulke': 'TR'},
#  {'ID': '738753',
#   'isim': 'Tirebolu',
#   'enlem': '41.006939',
#   'boylam': '38.813889',
#   'ulke': 'TR'},
#  {'ID': '738858',
#   'isim': 'Tepecik',
#   'enlem': '41.029308',
#   'boylam': '28.549780',
#   'ulke': 'TR'},
#  {'ID': '738907',
#   'isim': 'Tekkekoy',
#   'enlem': '41.211670',
#   'boylam': '36.459999',
#   'ulke': 'TR'},
#  {'ID': '739015',
#   'isim': 'Tasova',
#   'enlem': '40.759720',
#   'boylam': '36.322498',
#   'ulke': 'TR'},
#  {'ID': '739061',
#   'isim': 'Taskopru',
#   'enlem': '41.509800',
#   'boylam': '34.214142',
#   'ulke': 'TR'},
#  {'ID': '739209',
#   'isim': 'Susehri',
#   'enlem': '40.164440',
#   'boylam': '38.086670',
#   'ulke': 'TR'},
#  {'ID': '739215',
#   'isim': 'Surmene',
#   'enlem': '40.912579',
#   'boylam': '40.116760',
#   'ulke': 'TR'},
#  {'ID': '739251',
#   'isim': 'Suluova',
#   'enlem': '40.831280',
#   'boylam': '35.647881',
#   'ulke': 'TR'},
#  {'ID': '739549',
#   'isim': 'Sisli',
#   'enlem': '41.060459',
#   'boylam': '28.987169',
#   'ulke': 'TR'},
#  {'ID': '739914',
#   'isim': 'Sebinkarahisar',
#   'enlem': '40.288330',
#   'boylam': '38.423611',
#   'ulke': 'TR'},
#  {'ID': '740881',
#   'isim': 'Osmaneli',
#   'enlem': '40.357220',
#   'boylam': '30.014170',
#   'ulke': 'TR'},
#  {'ID': '740883',
#   'isim': 'Osmancik',
#   'enlem': '40.978180',
#   'boylam': '34.804699',
#   'ulke': 'TR'},
#  {'ID': '741240',
#   'isim': 'Of',
#   'enlem': '40.944580',
#   'boylam': '40.267460',
#   'ulke': 'TR'},
#  {'ID': '741347',
#   'isim': 'Nallihan',
#   'enlem': '40.185928',
#   'boylam': '31.351789',
#   'ulke': 'TR'},
#  {'ID': '741529',
#   'isim': 'Mimarsinan',
#   'enlem': '41.003151',
#   'boylam': '28.537680',
#   'ulke': 'TR'},
#  {'ID': '742238',
#   'isim': 'Kumru',
#   'enlem': '40.874439',
#   'boylam': '37.263889',
#   'ulke': 'TR'},
#  {'ID': '742658',
#   'isim': 'Korgan',
#   'enlem': '40.824718',
#   'boylam': '37.346668',
#   'ulke': 'TR'},
#  {'ID': '742902',
#   'isim': 'Kocaali',
#   'enlem': '41.053360',
#   'boylam': '30.852779',
#   'ulke': 'TR'},
#  {'ID': '743051',
#   'isim': 'Kizilcahamam',
#   'enlem': '40.469719',
#   'boylam': '32.650558',
#   'ulke': 'TR'},
#  {'ID': '743404',
#   'isim': 'Kestel',
#   'enlem': '40.198280',
#   'boylam': '29.212370',
#   'ulke': 'TR'},
#  {'ID': '743537',
#   'isim': 'Kelkit',
#   'enlem': '40.129780',
#   'boylam': '39.436069',
#   'ulke': 'TR'},
#  {'ID': '743615',
#   'isim': 'Kazan',
#   'enlem': '40.231670',
#   'boylam': '32.683891',
#   'ulke': 'TR'},
#  {'ID': '743818',
#   'isim': 'Kavakli',
#   'enlem': '41.092579',
#   'boylam': '28.331720',
#   'ulke': 'TR'},
#  {'ID': '744537',
#   'isim': 'Karacabey',
#   'enlem': '40.215248',
#   'boylam': '28.403780',
#   'ulke': 'TR'},
#  {'ID': '745028',
#   'isim': 'Izmit',
#   'enlem': '40.766941',
#   'boylam': '29.916941',
#   'ulke': 'TR'},
#  {'ID': '745076',
#   'isim': 'Iskilip',
#   'enlem': '40.735279',
#   'boylam': '34.473888',
#   'ulke': 'TR'},
#  {'ID': '745530',
#   'isim': 'Hopa',
#   'enlem': '41.405972',
#   'boylam': '41.437870',
#   'ulke': 'TR'},
#  {'ID': '745664',
#   'isim': 'Hendek',
#   'enlem': '40.799438',
#   'boylam': '30.748060',
#   'ulke': 'TR'},
#  {'ID': '746232',
#   'isim': 'Gursu',
#   'enlem': '40.218761',
#   'boylam': '29.194870',
#   'ulke': 'TR'},
#  {'ID': '746234',
#   'isim': 'Gurpinar',
#   'enlem': '40.990280',
#   'boylam': '28.615280',
#   'ulke': 'TR'},
#  {'ID': '746252',
#   'isim': 'Gurgentepe',
#   'enlem': '40.788330',
#   'boylam': '37.601669',
#   'ulke': 'TR'},
#  {'ID': '746881',
#   'isim': 'Giresun',
#   'enlem': '40.916981',
#   'boylam': '38.387409',
#   'ulke': 'TR'},
#  {'ID': '746898',
#   'isim': 'Geyve',
#   'enlem': '40.507500',
#   'boylam': '30.292500',
#   'ulke': 'TR'},
#  {'ID': '746940',
#   'isim': 'Gerede',
#   'enlem': '40.800831',
#   'boylam': '32.196941',
#   'ulke': 'TR'},
#  {'ID': '746983',
#   'isim': 'Gelibolu',
#   'enlem': '40.410278',
#   'boylam': '26.670830',
#   'ulke': 'TR'},
#  {'ID': '747135',
#   'isim': 'Ferizli',
#   'enlem': '40.940819',
#   'boylam': '30.485830',
#   'ulke': 'TR'},
#  {'ID': '747340',
#   'isim': 'Esenler',
#   'enlem': '41.043499',
#   'boylam': '28.876190',
#   'ulke': 'TR'},
#  {'ID': '747471',
#   'isim': 'Eregli',
#   'enlem': '41.282619',
#   'boylam': '31.418060',
#   'ulke': 'TR'},
#  {'ID': '747482',
#   'isim': 'Erdek',
#   'enlem': '40.399601',
#   'boylam': '27.793480',
#   'ulke': 'TR'},
#  {'ID': '747489',
#   'isim': 'Erbaa',
#   'enlem': '40.668892',
#   'boylam': '36.567501',
#   'ulke': 'TR'},
#  {'ID': '748167',
#   'isim': 'Devrek',
#   'enlem': '41.219170',
#   'boylam': '31.955830',
#   'ulke': 'TR'},
#  {'ID': '748870',
#   'isim': 'Cubuk',
#   'enlem': '40.238609',
#   'boylam': '33.032219',
#   'ulke': 'TR'},
#  {'ID': '749279',
#   'isim': 'Cerkes',
#   'enlem': '40.811642',
#   'boylam': '32.893581',
#   'ulke': 'TR'},
#  {'ID': '749502',
#   'isim': 'Cayeli',
#   'enlem': '41.092281',
#   'boylam': '40.729240',
#   'ulke': 'TR'},
#  {'ID': '749508',
#   'isim': 'Caycuma',
#   'enlem': '41.426392',
#   'boylam': '32.075562',
#   'ulke': 'TR'},
#  {'ID': '749704',
#   'isim': 'Carsamba',
#   'enlem': '41.198891',
#   'boylam': '36.721939',
#   'ulke': 'TR'},
#  {'ID': '750317',
#   'isim': 'Bulancak',
#   'enlem': '40.937168',
#   'boylam': '38.229069',
#   'ulke': 'TR'},
#  {'ID': '750468',
#   'isim': 'Boyabat',
#   'enlem': '41.468891',
#   'boylam': '34.766670',
#   'ulke': 'TR'},
#  {'ID': '750637',
#   'isim': 'Beypazari',
#   'enlem': '40.167500',
#   'boylam': '31.921110',
#   'ulke': 'TR'},
#  {'ID': '750735',
#   'isim': 'Besikduzu',
#   'enlem': '41.051991',
#   'boylam': '39.228439',
#   'ulke': 'TR'},
#  {'ID': '751057',
#   'isim': 'Bartin',
#   'enlem': '41.635830',
#   'boylam': '32.337502',
#   'ulke': 'TR'},
#  {'ID': '751838',
#   'isim': 'Arsin',
#   'enlem': '40.949581',
#   'boylam': '39.927559',
#   'ulke': 'TR'},
#  {'ID': '751931',
#   'isim': 'Arhavi',
#   'enlem': '41.349171',
#   'boylam': '41.306938',
#   'ulke': 'TR'},
#  {'ID': '751949',
#   'isim': 'Ardesen',
#   'enlem': '41.191109',
#   'boylam': '40.987499',
#   'ulke': 'TR'},
#  {'ID': '751971',
#   'isim': 'Arakli',
#   'enlem': '40.938541',
#   'boylam': '40.058418',
#   'ulke': 'TR'},
#  {'ID': '752184',
#   'isim': 'Alapli',
#   'enlem': '41.169399',
#   'boylam': '31.379169',
#   'ulke': 'TR'},
#  {'ID': '752278',
#   'isim': 'Alaca',
#   'enlem': '40.168331',
#   'boylam': '34.842499',
#   'ulke': 'TR'},
#  {'ID': '752584',
#   'isim': 'Akcakoca',
#   'enlem': '41.086632',
#   'boylam': '31.116230',
#   'ulke': 'TR'},
#  {'ID': '752627',
#   'isim': 'Akcaabat',
#   'enlem': '41.021198',
#   'boylam': '39.571461',
#   'ulke': 'TR'},
#  {'ID': '831432',
#   'isim': 'Espiye',
#   'enlem': '40.947941',
#   'boylam': '38.711479',
#   'ulke': 'TR'},
#  {'ID': '6354984',
#   'isim': 'merter keresteciler',
#   'enlem': '41.012951',
#   'boylam': '28.885929',
#   'ulke': 'TR'},
#  {'ID': '6354985',
#   'isim': 'guengoeren merter',
#   'enlem': '41.007111',
#   'boylam': '28.887951',
#   'ulke': 'TR'},
#  {'ID': '6692524',
#   'isim': 'Sarigerme',
#   'enlem': '36.715488',
#   'boylam': '28.704359',
#   'ulke': 'TR'},
#  {'ID': '6947637',
#   'isim': 'Atasehir',
#   'enlem': '40.983299',
#   'boylam': '29.116699',
#   'ulke': 'TR'},
#  {'ID': '6947639',
#   'isim': 'Basaksehir',
#   'enlem': '41.093071',
#   'boylam': '28.802031',
#   'ulke': 'TR'},
#  {'ID': '6947640',
#   'isim': 'Beylikduezue',
#   'enlem': '40.981998',
#   'boylam': '28.639900',
#   'ulke': 'TR'},
#  {'ID': '6947641',
#   'isim': 'Bueyuekcekmece',
#   'enlem': '41.020721',
#   'boylam': '28.585020',
#   'ulke': 'TR'},
#  {'ID': '6955677',
#   'isim': 'Cankaya',
#   'enlem': '39.917900',
#   'boylam': '32.862679',
#   'ulke': 'TR'},
#  {'ID': '7627067',
#   'isim': 'Bahcelievler',
#   'enlem': '41.002312',
#   'boylam': '28.859800',
#   'ulke': 'TR'},
#  {'ID': '7628416',
#   'isim': 'Sultangazi',
#   'enlem': '41.106522',
#   'boylam': '28.868469',
#   'ulke': 'TR'},
#  {'ID': '7628419',
#   'isim': 'Sultanbeyli',
#   'enlem': '40.960720',
#   'boylam': '29.270670',
#   'ulke': 'TR'},
#  {'ID': '7628420',
#   'isim': 'Sancaktepe',
#   'enlem': '41.002441',
#   'boylam': '29.231871',
#   'ulke': 'TR'},
#  {'ID': '7701384',
#   'isim': 'Karabaglar',
#   'enlem': '38.373959',
#   'boylam': '27.135201',
#   'ulke': 'TR'},
#  {'ID': '295781',
#   'isim': 'Demre',
#   'enlem': '36.244438',
#   'boylam': '29.985001',
#   'ulke': 'TR'},
#  {'ID': '295982',
#   'isim': 'Zara',
#   'enlem': '39.897781',
#   'boylam': '37.758331',
#   'ulke': 'TR'},
#  {'ID': '296138',
#   'isim': 'Yumurtalik',
#   'enlem': '36.766670',
#   'boylam': '35.783329',
#   'ulke': 'TR'},
#  {'ID': '296247',
#   'isim': 'Yukarisalat',
#   'enlem': '37.840000',
#   'boylam': '40.894169',
#   'ulke': 'TR'},
#  {'ID': '296644',
#   'isim': 'Yolbasi',
#   'enlem': '37.388920',
#   'boylam': '41.317131',
#   'ulke': 'TR'},
#  {'ID': '296653',
#   'isim': 'Yolagzi',
#   'enlem': '37.524841',
#   'boylam': '41.353569',
#   'ulke': 'TR'},
#  {'ID': '296791',
#   'isim': 'Yesilyurt',
#   'enlem': '38.297218',
#   'boylam': '38.249722',
#   'ulke': 'TR'},
#  {'ID': '296823',
#   'isim': 'Yesilova',
#   'enlem': '37.508060',
#   'boylam': '29.754721',
#   'ulke': 'TR'},
#  {'ID': '296860',
#   'isim': 'Yesilhisar',
#   'enlem': '38.349720',
#   'boylam': '35.086670',
#   'ulke': 'TR'},
#  {'ID': '296885',
#   'isim': 'Yesilalan',
#   'enlem': '37.463520',
#   'boylam': '40.788120',
#   'ulke': 'TR'},
#  {'ID': '296942',
#   'isim': 'Yenisarbademli',
#   'enlem': '37.707779',
#   'boylam': '31.386391',
#   'ulke': 'TR'},
#  {'ID': '296950',
#   'isim': 'Yenipazar',
#   'enlem': '37.824188',
#   'boylam': '28.197170',
#   'ulke': 'TR'},
#  {'ID': '297027',
#   'isim': 'Yenikoy',
#   'enlem': '37.881111',
#   'boylam': '41.049721',
#   'ulke': 'TR'},
#  {'ID': '297099',
#   'isim': 'Yenifakili',
#   'enlem': '39.211418',
#   'boylam': '35.000359',
#   'ulke': 'TR'},
#  {'ID': '297119',
#   'isim': 'Altpinar',
#   'enlem': '39.204170',
#   'boylam': '32.747780',
#   'ulke': 'TR'},
#  {'ID': '297148',
#   'isim': 'Yenice',
#   'enlem': '39.760899',
#   'boylam': '28.907280',
#   'ulke': 'TR'},
#  {'ID': '297371',
#   'isim': 'Yazihan',
#   'enlem': '38.594719',
#   'boylam': '38.180000',
#   'ulke': 'TR'},
#  {'ID': '297461',
#   'isim': 'Yayladere',
#   'enlem': '39.226139',
#   'boylam': '40.069500',
#   'ulke': 'TR'},
#  {'ID': '297466',
#   'isim': 'Yayladagi',
#   'enlem': '35.902500',
#   'boylam': '36.062721',
#   'ulke': 'TR'},
#  {'ID': '297532',
#   'isim': 'Yavuzeli',
#   'enlem': '37.317719',
#   'boylam': '37.568241',
#   'ulke': 'TR'},
#  {'ID': '297628',
#   'isim': 'Yarma',
#   'enlem': '37.811489',
#   'boylam': '32.882778',
#   'ulke': 'TR'},
#  {'ID': '297839',
#   'isim': 'Yalihuyuk',
#   'enlem': '37.300770',
#   'boylam': '32.085480',
#   'ulke': 'TR'},
#  {'ID': '298198',
#   'isim': 'Uzungecit',
#   'enlem': '37.494720',
#   'boylam': '42.993328',
#   'ulke': 'TR'},
#  {'ID': '298378',
#   'isim': 'Uluyatir',
#   'enlem': '36.963329',
#   'boylam': '37.693611',
#   'ulke': 'TR'},
#  {'ID': '298433',
#   'isim': 'Uludere',
#   'enlem': '37.445000',
#   'boylam': '42.861671',
#   'ulke': 'TR'},
#  {'ID': '298454',
#   'isim': 'Ulubey',
#   'enlem': '38.419868',
#   'boylam': '29.291290',
#   'ulke': 'TR'},
#  {'ID': '298471',
#   'isim': 'Ulas',
#   'enlem': '39.444920',
#   'boylam': '37.039001',
#   'ulke': 'TR'},
#  {'ID': '298485',
#   'isim': 'Ula',
#   'enlem': '37.104912',
#   'boylam': '28.416670',
#   'ulke': 'TR'},
#  {'ID': '298533',
#   'isim': 'Kerh',
#   'enlem': '37.825241',
#   'boylam': '40.543610',
#   'ulke': 'TR'},
#  {'ID': '298647',
#   'isim': 'Tuzlukcu',
#   'enlem': '38.477779',
#   'boylam': '31.626390',
#   'ulke': 'TR'},
#  {'ID': '298728',
#   'isim': 'Tut',
#   'enlem': '37.795292',
#   'boylam': '37.916100',
#   'ulke': 'TR'},
#  {'ID': '298882',
#   'isim': 'Tufanbeyli',
#   'enlem': '38.263329',
#   'boylam': '36.220558',
#   'ulke': 'TR'},
#  {'ID': '298977',
#   'isim': 'Toprakkale',
#   'enlem': '37.068550',
#   'boylam': '36.146610',
#   'ulke': 'TR'},
#  {'ID': '299054',
#   'isim': 'Tomarza',
#   'enlem': '38.447220',
#   'boylam': '35.799171',
#   'ulke': 'TR'},
#  {'ID': '299268',
#   'isim': 'Tercan',
#   'enlem': '39.779442',
#   'boylam': '40.392502',
#   'ulke': 'TR'},
#  {'ID': '299413',
#   'isim': 'Tekman',
#   'enlem': '39.643608',
#   'boylam': '41.507778',
#   'ulke': 'TR'},
#  {'ID': '299499',
#   'isim': 'Tefenni',
#   'enlem': '37.309681',
#   'boylam': '29.775379',
#   'ulke': 'TR'},
#  {'ID': '299575',
#   'isim': 'Tavas',
#   'enlem': '37.573509',
#   'boylam': '29.070580',
#   'ulke': 'TR'},
#  {'ID': '299701',
#   'isim': 'Taslicay',
#   'enlem': '39.633610',
#   'boylam': '43.375000',
#   'ulke': 'TR'},
#  {'ID': '299755',
#   'isim': 'Taskent',
#   'enlem': '36.924301',
#   'boylam': '32.491310',
#   'ulke': 'TR'},
#  {'ID': '300030',
#   'isim': 'Pavlu Cebel',
#   'enlem': '37.500580',
#   'boylam': '30.947760',
#   'ulke': 'TR'},
#  {'ID': '300087',
#   'isim': 'Avine',
#   'enlem': '37.584999',
#   'boylam': '40.737221',
#   'ulke': 'TR'},
#  {'ID': '300141',
#   'isim': 'Sulusaray',
#   'enlem': '39.993889',
#   'boylam': '36.084042',
#   'ulke': 'TR'},
#  {'ID': '300201',
#   'isim': 'Sultandagi',
#   'enlem': '38.531109',
#   'boylam': '31.228060',
#   'ulke': 'TR'},
#  {'ID': '300438',
#   'isim': 'Kindirip',
#   'enlem': '37.447029',
#   'boylam': '41.221039',
#   'ulke': 'TR'},
#  {'ID': '300593',
#   'isim': 'Sivrihisar',
#   'enlem': '39.450371',
#   'boylam': '31.534090',
#   'ulke': 'TR'},
#  {'ID': '300601',
#   'isim': 'Sivrice',
#   'enlem': '38.448158',
#   'boylam': '39.308449',
#   'ulke': 'TR'},
#  {'ID': '300616',
#   'isim': 'Sivasli',
#   'enlem': '38.499439',
#   'boylam': '29.683611',
#   'ulke': 'TR'},
#  {'ID': '300632',
#   'isim': 'Sirvan',
#   'enlem': '38.062401',
#   'boylam': '42.029179',
#   'ulke': 'TR'},
#  {'ID': '300635',
#   'isim': 'Tililan',
#   'enlem': '37.377781',
#   'boylam': '42.033890',
#   'ulke': 'TR'},
#  {'ID': '300732',
#   'isim': 'Sindirgi',
#   'enlem': '39.241280',
#   'boylam': '28.178419',
#   'ulke': 'TR'},
#  {'ID': '300743',
#   'isim': 'Sincik',
#   'enlem': '38.036751',
#   'boylam': '38.614868',
#   'ulke': 'TR'},
#  {'ID': '300754',
#   'isim': 'Sincanli',
#   'enlem': '38.744438',
#   'boylam': '30.242781',
#   'ulke': 'TR'},
#  {'ID': '300920',
#   'isim': 'Seyitgazi',
#   'enlem': '39.444721',
#   'boylam': '30.694719',
#   'ulke': 'TR'},
#  {'ID': '301158',
#   'isim': 'Senyurt',
#   'enlem': '37.078861',
#   'boylam': '40.644081',
#   'ulke': 'TR'},
#  {'ID': '301161',
#   'isim': 'Senoba',
#   'enlem': '37.461941',
#   'boylam': '42.713058',
#   'ulke': 'TR'},
#  {'ID': '301167',
#   'isim': 'Ebish',
#   'enlem': '37.463902',
#   'boylam': '41.190571',
#   'ulke': 'TR'},
#  {'ID': '301238',
#   'isim': 'Side',
#   'enlem': '36.766720',
#   'boylam': '31.388519',
#   'ulke': 'TR'},
#  {'ID': '301251',
#   'isim': 'Selendi',
#   'enlem': '38.744438',
#   'boylam': '28.867781',
#   'ulke': 'TR'},
#  {'ID': '301290',
#   'isim': 'Sekili',
#   'enlem': '36.978329',
#   'boylam': '37.673328',
#   'ulke': 'TR'},
#  {'ID': '301353',
#   'isim': 'Sefaatli',
#   'enlem': '39.504299',
#   'boylam': '34.756302',
#   'ulke': 'TR'},
#  {'ID': '301431',
#   'isim': 'Savur',
#   'enlem': '37.538841',
#   'boylam': '40.887680',
#   'ulke': 'TR'},
#  {'ID': '301453',
#   'isim': 'Savastepe',
#   'enlem': '39.383190',
#   'boylam': '27.656120',
#   'ulke': 'TR'},
#  {'ID': '301492',
#   'isim': 'Saruhanli',
#   'enlem': '38.734550',
#   'boylam': '27.568110',
#   'ulke': 'TR'},
#  {'ID': '301529',
#   'isim': 'Sarmansuyu',
#   'enlem': '38.418030',
#   'boylam': '43.236488',
#   'ulke': 'TR'},
#  {'ID': '301546',
#   'isim': 'Sariz',
#   'enlem': '38.479172',
#   'boylam': '36.498981',
#   'ulke': 'TR'},
#  {'ID': '301566',
#   'isim': 'Sariyahsi',
#   'enlem': '38.983490',
#   'boylam': '33.841358',
#   'ulke': 'TR'},
#  {'ID': '301567',
#   'isim': 'Sariveliler',
#   'enlem': '36.691299',
#   'boylam': '32.619579',
#   'ulke': 'TR'},
#  {'ID': '301609',
#   'isim': 'Sarioglan',
#   'enlem': '39.076939',
#   'boylam': '35.966709',
#   'ulke': 'TR'},
#  {'ID': '301731',
#   'isim': 'Sarigol',
#   'enlem': '38.239529',
#   'boylam': '28.696630',
#   'ulke': 'TR'},
#  {'ID': '301824',
#   'isim': 'Sarayonu',
#   'enlem': '38.262009',
#   'boylam': '32.404572',
#   'ulke': 'TR'},
#  {'ID': '301829',
#   'isim': 'Saraykent',
#   'enlem': '39.693611',
#   'boylam': '35.511108',
#   'ulke': 'TR'},
#  {'ID': '301884',
#   'isim': 'Saphane',
#   'enlem': '39.027302',
#   'boylam': '29.222179',
#   'ulke': 'TR'},
#  {'ID': '301943',
#   'isim': 'Samsat',
#   'enlem': '37.581940',
#   'boylam': '38.474171',
#   'ulke': 'TR'},
#  {'ID': '302150',
#   'isim': 'Saimbeyli',
#   'enlem': '37.986320',
#   'boylam': '36.090561',
#   'ulke': 'TR'},
#  {'ID': '302401',
#   'isim': 'Refahiye',
#   'enlem': '39.900829',
#   'boylam': '38.766670',
#   'ulke': 'TR'},
#  {'ID': '302645',
#   'isim': 'Pinardere',
#   'enlem': '37.472881',
#   'boylam': '40.822128',
#   'ulke': 'TR'},
#  {'ID': '302667',
#   'isim': 'Pinarbasi',
#   'enlem': '38.722851',
#   'boylam': '36.393139',
#   'ulke': 'TR'},
#  {'ID': '302720',
#   'isim': 'Pervari',
#   'enlem': '37.935730',
#   'boylam': '42.549271',
#   'ulke': 'TR'},
#  {'ID': '302781',
#   'isim': 'Pazaryeri',
#   'enlem': '39.993950',
#   'boylam': '29.904240',
#   'ulke': 'TR'},
#  {'ID': '302787',
#   'isim': 'Pazarlar',
#   'enlem': '38.994999',
#   'boylam': '29.125830',
#   'ulke': 'TR'},
#  {'ID': '302903',
#   'isim': 'Pamukkale',
#   'enlem': '37.916439',
#   'boylam': '29.117290',
#   'ulke': 'TR'},
#  {'ID': '302912',
#   'isim': 'Palu',
#   'enlem': '38.691669',
#   'boylam': '39.928890',
#   'ulke': 'TR'},
#  {'ID': '303022',
#   'isim': 'Ozalp',
#   'enlem': '38.654770',
#   'boylam': '43.993011',
#   'ulke': 'TR'},
#  {'ID': '303046',
#   'isim': 'Oymatas',
#   'enlem': '37.799068',
#   'boylam': '41.020828',
#   'ulke': 'TR'},
#  {'ID': '303062',
#   'isim': 'Oyali',
#   'enlem': '37.228889',
#   'boylam': '41.740559',
#   'ulke': 'TR'},
#  {'ID': '303092',
#   'isim': 'Ovakavagi',
#   'enlem': '37.710789',
#   'boylam': '32.934818',
#   'ulke': 'TR'},
#  {'ID': '303147',
#   'isim': 'Otlukbeli',
#   'enlem': '39.973961',
#   'boylam': '40.023720',
#   'ulke': 'TR'},
#  {'ID': '303305',
#   'isim': 'Ortakoy',
#   'enlem': '37.222149',
#   'boylam': '40.785172',
#   'ulke': 'TR'},
#  {'ID': '303353',
#   'isim': 'Ortaca',
#   'enlem': '37.473610',
#   'boylam': '41.550560',
#   'ulke': 'TR'},
#  {'ID': '303357',
#   'isim': 'Ortabag',
#   'enlem': '37.395828',
#   'boylam': '42.913609',
#   'ulke': 'TR'},
#  {'ID': '303532',
#   'isim': 'Omerli',
#   'enlem': '37.402222',
#   'boylam': '40.954090',
#   'ulke': 'TR'},
#  {'ID': '303642',
#   'isim': 'Oguzeli',
#   'enlem': '36.965721',
#   'boylam': '37.513390',
#   'ulke': 'TR'},
#  {'ID': '303763',
#   'isim': 'Nurhak',
#   'enlem': '37.962879',
#   'boylam': '37.420231',
#   'ulke': 'TR'},
#  {'ID': '304009',
#   'isim': 'Mutki',
#   'enlem': '38.409439',
#   'boylam': '41.918610',
#   'ulke': 'TR'},
#  {'ID': '304078',
#   'isim': 'Musabeyli',
#   'enlem': '36.886391',
#   'boylam': '36.918610',
#   'ulke': 'TR'},
#  {'ID': '304110',
#   'isim': 'Muratli',
#   'enlem': '36.961670',
#   'boylam': '40.100559',
#   'ulke': 'TR'},
#  {'ID': '304349',
#   'isim': 'Balveren',
#   'enlem': '37.483330',
#   'boylam': '42.546940',
#   'ulke': 'TR'},
#  {'ID': '304414',
#   'isim': 'Mezrea',
#   'enlem': '37.662571',
#   'boylam': '43.188850',
#   'ulke': 'TR'},
#  {'ID': '304738',
#   'isim': 'Mazgirt',
#   'enlem': '39.020039',
#   'boylam': '39.606041',
#   'ulke': 'TR'},
#  {'ID': '305182',
#   'isim': 'Kuyulusebil',
#   'enlem': '38.653889',
#   'boylam': '32.529720',
#   'ulke': 'TR'},
#  {'ID': '305210',
#   'isim': 'Kuyucak',
#   'enlem': '37.913300',
#   'boylam': '28.459169',
#   'ulke': 'TR'},
#  {'ID': '305699',
#   'isim': 'Kumcati',
#   'enlem': '37.465660',
#   'boylam': '42.283642',
#   'ulke': 'TR'},
#  {'ID': '305737',
#   'isim': 'Kulucak',
#   'enlem': '38.882778',
#   'boylam': '37.672779',
#   'ulke': 'TR'},
#  {'ID': '306116',
#   'isim': 'Kozakli',
#   'enlem': '39.216431',
#   'boylam': '34.849091',
#   'ulke': 'TR'},
#  {'ID': '306285',
#   'isim': 'Kosk',
#   'enlem': '37.853329',
#   'boylam': '28.051670',
#   'ulke': 'TR'},
#  {'ID': '306476',
#   'isim': 'Korkut',
#   'enlem': '38.739079',
#   'boylam': '41.782162',
#   'ulke': 'TR'},
#  {'ID': '306537',
#   'isim': 'Koprubasi',
#   'enlem': '38.749722',
#   'boylam': '28.404720',
#   'ulke': 'TR'},
#  {'ID': '306612',
#   'isim': 'Konalga',
#   'enlem': '37.859879',
#   'boylam': '43.096851',
#   'ulke': 'TR'},
#  {'ID': '306859',
#   'isim': 'Goecek',
#   'enlem': '36.758179',
#   'boylam': '28.928160',
#   'ulke': 'TR'},
#  {'ID': '306908',
#   'isim': 'Kocarli',
#   'enlem': '37.761131',
#   'boylam': '27.705820',
#   'ulke': 'TR'},
#  {'ID': '306935',
#   'isim': 'Kocakoy',
#   'enlem': '38.290279',
#   'boylam': '40.502499',
#   'ulke': 'TR'},
#  {'ID': '307129',
#   'isim': 'Kiziloren',
#   'enlem': '38.258060',
#   'boylam': '30.151670',
#   'ulke': 'TR'},
#  {'ID': '307727',
#   'isim': 'Kiraz',
#   'enlem': '38.230560',
#   'boylam': '28.204439',
#   'ulke': 'TR'},
#  {'ID': '307786',
#   'isim': 'Kinik',
#   'enlem': '39.087219',
#   'boylam': '27.383329',
#   'ulke': 'TR'},
#  {'ID': '307939',
#   'isim': 'Kilavuz',
#   'enlem': '37.478329',
#   'boylam': '41.780560',
#   'ulke': 'TR'},
#  {'ID': '308217',
#   'isim': 'Kemer',
#   'enlem': '37.352219',
#   'boylam': '30.063061',
#   'ulke': 'TR'},
#  {'ID': '308233',
#   'isim': 'Kemah',
#   'enlem': '39.601669',
#   'boylam': '39.038059',
#   'ulke': 'TR'},
#  {'ID': '308261',
#   'isim': 'Keles',
#   'enlem': '39.913609',
#   'boylam': '29.229441',
#   'ulke': 'TR'},
#  {'ID': '308365',
#   'isim': 'Keciborlu',
#   'enlem': '37.942501',
#   'boylam': '30.302219',
#   'ulke': 'TR'},
#  {'ID': '308400',
#   'isim': 'Kazimkarabekir',
#   'enlem': '37.230282',
#   'boylam': '32.958889',
#   'ulke': 'TR'},
#  {'ID': '308572',
#   'isim': 'Kayapinar',
#   'enlem': '37.557350',
#   'boylam': '41.164959',
#   'ulke': 'TR'},
#  {'ID': '308697',
#   'isim': 'Kayabaglar',
#   'enlem': '37.982498',
#   'boylam': '41.665279',
#   'ulke': 'TR'},
#  {'ID': '308998',
#   'isim': 'Aladag',
#   'enlem': '37.548500',
#   'boylam': '35.396030',
#   'ulke': 'TR'},
#  {'ID': '309008',
#   'isim': 'Karpuzlu',
#   'enlem': '37.558609',
#   'boylam': '27.835279',
#   'ulke': 'TR'},
#  {'ID': '309032',
#   'isim': 'Karliova',
#   'enlem': '39.298328',
#   'boylam': '41.014172',
#   'ulke': 'TR'},
#  {'ID': '309134',
#   'isim': 'Karkamis',
#   'enlem': '36.833328',
#   'boylam': '37.998058',
#   'ulke': 'TR'},
#  {'ID': '309199',
#   'isim': 'Karayazi',
#   'enlem': '39.702801',
#   'boylam': '42.145611',
#   'ulke': 'TR'},
#  {'ID': '309312',
#   'isim': 'Karatas',
#   'enlem': '36.582039',
#   'boylam': '35.370140',
#   'ulke': 'TR'},
#  {'ID': '309512',
#   'isim': 'Karamanli',
#   'enlem': '37.373009',
#   'boylam': '29.823080',
#   'ulke': 'TR'},
#  {'ID': '309554',
#   'isim': 'Karalar',
#   'enlem': '37.299171',
#   'boylam': '41.672501',
#   'ulke': 'TR'},
#  {'ID': '309610',
#   'isim': 'Karakoyunlu',
#   'enlem': '39.870361',
#   'boylam': '43.630138',
#   'ulke': 'TR'},
#  {'ID': '309705',
#   'isim': 'Karakecili',
#   'enlem': '39.594170',
#   'boylam': '33.377781',
#   'ulke': 'TR'},
#  {'ID': '309758',
#   'isim': 'Karaisali',
#   'enlem': '37.256672',
#   'boylam': '35.058891',
#   'ulke': 'TR'},
#  {'ID': '309821',
#   'isim': 'Karahalli',
#   'enlem': '38.320831',
#   'boylam': '29.530279',
#   'ulke': 'TR'},
#  {'ID': '310044',
#   'isim': 'Karacasu',
#   'enlem': '37.728161',
#   'boylam': '28.605690',
#   'ulke': 'TR'},
#  {'ID': '310200',
#   'isim': 'Karaburun',
#   'enlem': '38.639671',
#   'boylam': '26.511101',
#   'ulke': 'TR'},
#  {'ID': '310677',
#   'isim': 'Kalkan',
#   'enlem': '36.265099',
#   'boylam': '29.413691',
#   'ulke': 'TR'},
#  {'ID': '310784',
#   'isim': 'Kale',
#   'enlem': '39.033329',
#   'boylam': '38.000000',
#   'ulke': 'TR'},
#  {'ID': '310789',
#   'isim': 'Kale',
#   'enlem': '37.439171',
#   'boylam': '28.845280',
#   'ulke': 'TR'},
#  {'ID': '310888',
#   'isim': 'Kadisehri',
#   'enlem': '39.995682',
#   'boylam': '35.791931',
#   'ulke': 'TR'},
#  {'ID': '310982',
#   'isim': 'Kabala',
#   'enlem': '37.349960',
#   'boylam': '40.814629',
#   'ulke': 'TR'},
#  {'ID': '311054',
#   'isim': 'Ivrindi',
#   'enlem': '39.583889',
#   'boylam': '27.486389',
#   'ulke': 'TR'},
#  {'ID': '311193',
#   'isim': 'Iscehisar',
#   'enlem': '38.861938',
#   'boylam': '30.750280',
#   'ulke': 'TR'},
#  {'ID': '311264',
#   'isim': 'Inonu',
#   'enlem': '37.316669',
#   'boylam': '33.766670',
#   'ulke': 'TR'},
#  {'ID': '311433',
#   'isim': 'Imranli',
#   'enlem': '39.875439',
#   'boylam': '38.113579',
#   'ulke': 'TR'},
#  {'ID': '311533',
#   'isim': 'Ilica',
#   'enlem': '39.946270',
#   'boylam': '41.109058',
#   'ulke': 'TR'},
#  {'ID': '311547',
#   'isim': 'Ilic',
#   'enlem': '39.455029',
#   'boylam': '38.563999',
#   'ulke': 'TR'},
#  {'ID': '311628',
#   'isim': 'Aviski',
#   'enlem': '37.965771',
#   'boylam': '41.329281',
#   'ulke': 'TR'},
#  {'ID': '311645',
#   'isim': 'Ihsaniye',
#   'enlem': '39.029160',
#   'boylam': '30.416389',
#   'ulke': 'TR'},
#  {'ID': '311777',
#   'isim': 'Huyuk',
#   'enlem': '37.953880',
#   'boylam': '31.596390',
#   'ulke': 'TR'},
#  {'ID': '311962',
#   'isim': 'Honaz',
#   'enlem': '37.757301',
#   'boylam': '29.269960',
#   'ulke': 'TR'},
#  {'ID': '311994',
#   'isim': 'Hocalar',
#   'enlem': '38.578239',
#   'boylam': '29.967680',
#   'ulke': 'TR'},
#  {'ID': '312073',
#   'isim': 'Hisarkoy',
#   'enlem': '37.600941',
#   'boylam': '41.227989',
#   'ulke': 'TR'},
#  {'ID': '312143',
#   'isim': 'Hilal',
#   'enlem': '37.475281',
#   'boylam': '42.785831',
#   'ulke': 'TR'},
#  {'ID': '312245',
#   'isim': 'Hekimhan',
#   'enlem': '38.817959',
#   'boylam': '37.931171',
#   'ulke': 'TR'},
#  {'ID': '312253',
#   'isim': 'Hazro',
#   'enlem': '38.253330',
#   'boylam': '40.781670',
#   'ulke': 'TR'},
#  {'ID': '312289',
#   'isim': 'Haymana',
#   'enlem': '39.432121',
#   'boylam': '32.497318',
#   'ulke': 'TR'},
#  {'ID': '312355',
#   'isim': 'Havran',
#   'enlem': '39.558331',
#   'boylam': '27.098330',
#   'ulke': 'TR'},
#  {'ID': '312405',
#   'isim': 'Hassa',
#   'enlem': '36.799438',
#   'boylam': '36.517780',
#   'ulke': 'TR'},
#  {'ID': '312479',
#   'isim': 'Hasankeyf',
#   'enlem': '37.713081',
#   'boylam': '41.414589',
#   'ulke': 'TR'},
#  {'ID': '312504',
#   'isim': 'Hasanbeyli',
#   'enlem': '37.137180',
#   'boylam': '36.559330',
#   'ulke': 'TR'},
#  {'ID': '312531',
#   'isim': 'Harran',
#   'enlem': '36.860001',
#   'boylam': '39.031391',
#   'ulke': 'TR'},
#  {'ID': '312699',
#   'isim': 'Han',
#   'enlem': '36.950809',
#   'boylam': '40.198551',
#   'ulke': 'TR'},
#  {'ID': '312731',
#   'isim': 'Hamur',
#   'enlem': '39.608891',
#   'boylam': '42.989170',
#   'ulke': 'TR'},
#  {'ID': '312817',
#   'isim': 'Halkapinar',
#   'enlem': '37.433941',
#   'boylam': '34.187431',
#   'ulke': 'TR'},
#  {'ID': '312894',
#   'isim': 'Hafik',
#   'enlem': '39.856392',
#   'boylam': '37.386391',
#   'ulke': 'TR'},
#  {'ID': '313110',
#   'isim': 'Hacibektas',
#   'enlem': '38.940769',
#   'boylam': '34.557701',
#   'ulke': 'TR'},
#  {'ID': '313199',
#   'isim': 'Guzelyurt',
#   'enlem': '38.277222',
#   'boylam': '34.371941',
#   'ulke': 'TR'},
#  {'ID': '313314',
#   'isim': 'Gurun',
#   'enlem': '38.722252',
#   'boylam': '37.270969',
#   'ulke': 'TR'},
#  {'ID': '313500',
#   'isim': 'Guneren',
#   'enlem': '36.734169',
#   'boylam': '39.088612',
#   'ulke': 'TR'},
#  {'ID': '313526',
#   'isim': 'Eksere',
#   'enlem': '36.813389',
#   'boylam': '31.999710',
#   'ulke': 'TR'},
#  {'ID': '313635',
#   'isim': 'Becuh',
#   'enlem': '37.392502',
#   'boylam': '42.988060',
#   'ulke': 'TR'},
#  {'ID': '313640',
#   'isim': 'Gulveren',
#   'enlem': '37.487782',
#   'boylam': '41.494438',
#   'ulke': 'TR'},
#  {'ID': '313658',
#   'isim': 'Gulsehir',
#   'enlem': '38.745941',
#   'boylam': '34.625240',
#   'ulke': 'TR'},
#  {'ID': '313713',
#   'isim': 'Guellue',
#   'enlem': '38.269718',
#   'boylam': '29.108061',
#   'ulke': 'TR'},
#  {'ID': '313794',
#   'isim': 'Baraniferho',
#   'enlem': '37.469719',
#   'boylam': '41.914169',
#   'ulke': 'TR'},
#  {'ID': '313825',
#   'isim': 'Gozpinar',
#   'enlem': '37.978260',
#   'boylam': '41.457008',
#   'ulke': 'TR'},
#  {'ID': '313922',
#   'isim': 'Bisbin',
#   'enlem': '37.338612',
#   'boylam': '42.570278',
#   'ulke': 'TR'},
#  {'ID': '313947',
#   'isim': 'Goereme',
#   'enlem': '38.643700',
#   'boylam': '34.835289',
#   'ulke': 'TR'},
#  {'ID': '313960',
#   'isim': 'Gordes',
#   'enlem': '38.932781',
#   'boylam': '28.289419',
#   'ulke': 'TR'},
#  {'ID': '313973',
#   'isim': 'Gonen',
#   'enlem': '37.956390',
#   'boylam': '30.511400',
#   'ulke': 'TR'},
#  {'ID': '314038',
#   'isim': 'Golmarmara',
#   'enlem': '38.713890',
#   'boylam': '27.914169',
#   'ulke': 'TR'},
#  {'ID': '314072',
#   'isim': 'Golhisar',
#   'enlem': '37.145901',
#   'boylam': '29.508760',
#   'ulke': 'TR'},
#  {'ID': '314350',
#   'isim': 'Civankan',
#   'enlem': '37.905830',
#   'boylam': '41.873329',
#   'ulke': 'TR'},
#  {'ID': '314364',
#   'isim': 'Selah',
#   'enlem': '37.205002',
#   'boylam': '40.694439',
#   'ulke': 'TR'},
#  {'ID': '314557',
#   'isim': 'Gevas',
#   'enlem': '38.296810',
#   'boylam': '43.108250',
#   'ulke': 'TR'},
#  {'ID': '314573',
#   'isim': 'Germencik',
#   'enlem': '37.870560',
#   'boylam': '27.602831',
#   'ulke': 'TR'},
#  {'ID': '314588',
#   'isim': 'Gerger',
#   'enlem': '37.950001',
#   'boylam': '39.016670',
#   'ulke': 'TR'},
#  {'ID': '314608',
#   'isim': 'Gerdzhyush',
#   'enlem': '37.565102',
#   'boylam': '41.391609',
#   'ulke': 'TR'},
#  {'ID': '314677',
#   'isim': 'Gelinkaya',
#   'enlem': '37.417011',
#   'boylam': '41.293011',
#   'ulke': 'TR'},
#  {'ID': '314698',
#   'isim': 'Gelendost',
#   'enlem': '38.120831',
#   'boylam': '31.015280',
#   'ulke': 'TR'},
#  {'ID': '314996',
#   'isim': 'Felahiye',
#   'enlem': '39.090561',
#   'boylam': '35.567219',
#   'ulke': 'TR'},
#  {'ID': '315000',
#   'isim': 'Feke',
#   'enlem': '37.814461',
#   'boylam': '35.912319',
#   'ulke': 'TR'},
#  {'ID': '315132',
#   'isim': 'Evciler',
#   'enlem': '38.041389',
#   'boylam': '29.886669',
#   'ulke': 'TR'},
#  {'ID': '315183',
#   'isim': 'Esme',
#   'enlem': '38.399761',
#   'boylam': '28.969049',
#   'ulke': 'TR'},
#  {'ID': '315378',
#   'isim': 'Eruh',
#   'enlem': '37.751671',
#   'boylam': '42.181110',
#   'ulke': 'TR'},
#  {'ID': '315617',
#   'isim': 'Emirgazi',
#   'enlem': '37.902222',
#   'boylam': '33.837219',
#   'ulke': 'TR'},
#  {'ID': '315800',
#   'isim': 'Elbeyli',
#   'enlem': '36.674171',
#   'boylam': '37.466671',
#   'ulke': 'TR'},
#  {'ID': '315835',
#   'isim': 'Celeyke',
#   'enlem': '38.059738',
#   'boylam': '37.187859',
#   'ulke': 'TR'},
#  {'ID': '315953',
#   'isim': 'Egil',
#   'enlem': '38.257221',
#   'boylam': '40.082779',
#   'ulke': 'TR'},
#  {'ID': '316096',
#   'isim': 'Duruca',
#   'enlem': '37.093330',
#   'boylam': '41.308609',
#   'ulke': 'TR'},
#  {'ID': '316165',
#   'isim': 'Dumlupinar',
#   'enlem': '38.866669',
#   'boylam': '30.000000',
#   'ulke': 'TR'},
#  {'ID': '316330',
#   'isim': 'Domanic Kozluca',
#   'enlem': '39.799999',
#   'boylam': '29.616671',
#   'ulke': 'TR'},
#  {'ID': '316431',
#   'isim': 'Doganyol',
#   'enlem': '38.311840',
#   'boylam': '39.038189',
#   'ulke': 'TR'},
#  {'ID': '316466',
#   'isim': 'Dogankoy',
#   'enlem': '37.752769',
#   'boylam': '42.798012',
#   'ulke': 'TR'},
#  {'ID': '316473',
#   'isim': 'Dogankavak',
#   'enlem': '37.962372',
#   'boylam': '41.227291',
#   'ulke': 'TR'},
#  {'ID': '316475',
#   'isim': 'Doganhisar',
#   'enlem': '38.146301',
#   'boylam': '31.676479',
#   'ulke': 'TR'},
#  {'ID': '316497',
#   'isim': 'Doganca',
#   'enlem': '37.808331',
#   'boylam': '42.340000',
#   'ulke': 'TR'},
#  {'ID': '316544',
#   'isim': 'Divrigi',
#   'enlem': '39.370998',
#   'boylam': '38.113701',
#   'ulke': 'TR'},
#  {'ID': '316726',
#   'isim': 'Dikili',
#   'enlem': '39.070999',
#   'boylam': '26.890169',
#   'ulke': 'TR'},
#  {'ID': '316746',
#   'isim': 'Dicle',
#   'enlem': '38.375149',
#   'boylam': '40.072189',
#   'ulke': 'TR'},
#  {'ID': '316877',
#   'isim': 'Derinkuyu',
#   'enlem': '38.375099',
#   'boylam': '34.734192',
#   'ulke': 'TR'},
#  {'ID': '317049',
#   'isim': 'Derebucak',
#   'enlem': '37.391788',
#   'boylam': '31.509180',
#   'ulke': 'TR'},
#  {'ID': '317095',
#   'isim': 'Derbent',
#   'enlem': '38.014221',
#   'boylam': '32.016392',
#   'ulke': 'TR'},
#  {'ID': '317332',
#   'isim': 'Delice',
#   'enlem': '39.953709',
#   'boylam': '34.025871',
#   'ulke': 'TR'},
#  {'ID': '317496',
#   'isim': 'Dazkiri',
#   'enlem': '37.918610',
#   'boylam': '29.860559',
#   'ulke': 'TR'},
#  {'ID': '317837',
#   'isim': 'Cungus',
#   'enlem': '38.212502',
#   'boylam': '39.285561',
#   'ulke': 'TR'},
#  {'ID': '317953',
#   'isim': 'Cukurca',
#   'enlem': '37.248058',
#   'boylam': '43.613609',
#   'ulke': 'TR'},
#  {'ID': '318264',
#   'isim': 'Civril',
#   'enlem': '38.301392',
#   'boylam': '29.738609',
#   'ulke': 'TR'},
#  {'ID': '318506',
#   'isim': 'Cihanbeyli',
#   'enlem': '38.660721',
#   'boylam': '32.924370',
#   'ulke': 'TR'},
#  {'ID': '318526',
#   'isim': 'Serkan',
#   'enlem': '37.159439',
#   'boylam': '41.741669',
#   'ulke': 'TR'},
#  {'ID': '318603',
#   'isim': 'Cifteler',
#   'enlem': '39.383060',
#   'boylam': '31.039169',
#   'ulke': 'TR'},
#  {'ID': '318904',
#   'isim': 'Celikhan',
#   'enlem': '38.034168',
#   'boylam': '38.243328',
#   'ulke': 'TR'},
#  {'ID': '319069',
#   'isim': 'Cayiralan',
#   'enlem': '39.302780',
#   'boylam': '35.643890',
#   'ulke': 'TR'},
#  {'ID': '319118',
#   'isim': 'Cavuslu',
#   'enlem': '37.498611',
#   'boylam': '41.244171',
#   'ulke': 'TR'},
#  {'ID': '319487',
#   'isim': 'Candarli',
#   'enlem': '38.935032',
#   'boylam': '26.934000',
#   'ulke': 'TR'},
#  {'ID': '319670',
#   'isim': 'Anamas',
#   'enlem': '37.766670',
#   'boylam': '30.799999',
#   'ulke': 'TR'},
#  {'ID': '319787',
#   'isim': 'Caliskan',
#   'enlem': '37.297218',
#   'boylam': '42.643608',
#   'ulke': 'TR'},
#  {'ID': '320177',
#   'isim': 'Nikfer',
#   'enlem': '37.405418',
#   'boylam': '29.137270',
#   'ulke': 'TR'},
#  {'ID': '320374',
#   'isim': 'Buharkent',
#   'enlem': '37.963959',
#   'boylam': '28.742701',
#   'ulke': 'TR'},
#  {'ID': '320406',
#   'isim': 'Bunyan',
#   'enlem': '38.846298',
#   'boylam': '35.860321',
#   'ulke': 'TR'},
#  {'ID': '320437',
#   'isim': 'Buldan',
#   'enlem': '38.044998',
#   'boylam': '28.830561',
#   'ulke': 'TR'},
#  {'ID': '320606',
#   'isim': 'Bozkurt',
#   'enlem': '37.824169',
#   'boylam': '29.609720',
#   'ulke': 'TR'},
#  {'ID': '320647',
#   'isim': 'Bozdogan',
#   'enlem': '37.671341',
#   'boylam': '28.313950',
#   'ulke': 'TR'},
#  {'ID': '320700',
#   'isim': 'Bozcaada',
#   'enlem': '39.834999',
#   'boylam': '26.069719',
#   'ulke': 'TR'},
#  {'ID': '320745',
#   'isim': 'Bozalan',
#   'enlem': '37.328941',
#   'boylam': '42.264820',
#   'ulke': 'TR'},
#  {'ID': '320835',
#   'isim': 'Bostanci',
#   'enlem': '37.180000',
#   'boylam': '42.330002',
#   'ulke': 'TR'},
#  {'ID': '321088',
#   'isim': 'Binatli',
#   'enlem': '37.847980',
#   'boylam': '41.216358',
#   'ulke': 'TR'},
#  {'ID': '321184',
#   'isim': 'Beytussebap',
#   'enlem': '37.569439',
#   'boylam': '43.168060',
#   'ulke': 'TR'},
#  {'ID': '321219',
#   'isim': 'Beylikova',
#   'enlem': '39.686939',
#   'boylam': '31.205561',
#   'ulke': 'TR'},
#  {'ID': '321637',
#   'isim': 'Bekilli',
#   'enlem': '38.231049',
#   'boylam': '29.419701',
#   'ulke': 'TR'},
#  {'ID': '321673',
#   'isim': 'Begendik',
#   'enlem': '37.975559',
#   'boylam': '42.644169',
#   'ulke': 'TR'},
#  {'ID': '321750',
#   'isim': 'Baykan',
#   'enlem': '38.162659',
#   'boylam': '41.783329',
#   'ulke': 'TR'},
#  {'ID': '321814',
#   'isim': 'Bayat',
#   'enlem': '38.983059',
#   'boylam': '30.924721',
#   'ulke': 'TR'},
#  {'ID': '321887',
#   'isim': 'Basmakci',
#   'enlem': '37.897221',
#   'boylam': '30.011669',
#   'ulke': 'TR'},
#  {'ID': '321935',
#   'isim': 'Baskavak',
#   'enlem': '37.568241',
#   'boylam': '40.895802',
#   'ulke': 'TR'},
#  {'ID': '321940',
#   'isim': 'Baskale',
#   'enlem': '38.045261',
#   'boylam': '44.017181',
#   'ulke': 'TR'},
#  {'ID': '322076',
#   'isim': 'Balpinar',
#   'enlem': '37.868328',
#   'boylam': '41.054722',
#   'ulke': 'TR'},
#  {'ID': '322137',
#   'isim': 'Baliseyh',
#   'enlem': '39.914108',
#   'boylam': '33.723331',
#   'ulke': 'TR'},
#  {'ID': '322250',
#   'isim': 'Baklan',
#   'enlem': '37.976940',
#   'boylam': '29.608610',
#   'ulke': 'TR'},
#  {'ID': '322324',
#   'isim': 'Bahcesaray',
#   'enlem': '38.125340',
#   'boylam': '42.806740',
#   'ulke': 'TR'},
#  {'ID': '322618',
#   'isim': 'Babadag',
#   'enlem': '37.808849',
#   'boylam': '28.878771',
#   'ulke': 'TR'},
#  {'ID': '322692',
#   'isim': 'Ayvacik',
#   'enlem': '39.601109',
#   'boylam': '26.404720',
#   'ulke': 'TR'},
#  {'ID': '322810',
#   'isim': 'Aydinlar',
#   'enlem': '37.949108',
#   'boylam': '42.012100',
#   'ulke': 'TR'},
#  {'ID': '322817',
#   'isim': 'Ibradi',
#   'enlem': '37.096939',
#   'boylam': '31.599171',
#   'ulke': 'TR'},
#  {'ID': '322826',
#   'isim': 'Aydincik',
#   'enlem': '36.143700',
#   'boylam': '33.320160',
#   'ulke': 'TR'},
#  {'ID': '322887',
#   'isim': 'Avsallar',
#   'enlem': '36.616009',
#   'boylam': '31.780621',
#   'ulke': 'TR'},
#  {'ID': '323039',
#   'isim': 'Atabey',
#   'enlem': '37.950829',
#   'boylam': '30.638611',
#   'ulke': 'TR'},
#  {'ID': '323082',
#   'isim': 'Aslanapa',
#   'enlem': '39.215809',
#   'boylam': '29.869900',
#   'ulke': 'TR'},
#  {'ID': '323653',
#   'isim': 'Aricak',
#   'enlem': '38.563889',
#   'boylam': '40.134720',
#   'ulke': 'TR'},
#  {'ID': '323660',
#   'isim': 'Arguvan',
#   'enlem': '38.769951',
#   'boylam': '38.271198',
#   'ulke': 'TR'},
#  {'ID': '323721',
#   'isim': 'Arapgir',
#   'enlem': '39.041168',
#   'boylam': '38.495159',
#   'ulke': 'TR'},
#  {'ID': '323750',
#   'isim': 'Araban',
#   'enlem': '37.426670',
#   'boylam': '37.688999',
#   'ulke': 'TR'},
#  {'ID': '323797',
#   'isim': 'Andirin',
#   'enlem': '37.577572',
#   'boylam': '36.354919',
#   'ulke': 'TR'},
#  {'ID': '323806',
#   'isim': 'Andac',
#   'enlem': '37.355282',
#   'boylam': '43.265560',
#   'ulke': 'TR'},
#  {'ID': '323854',
#   'isim': 'Ambar',
#   'enlem': '37.853161',
#   'boylam': '40.527760',
#   'ulke': 'TR'},
#  {'ID': '323886',
#   'isim': 'Altinyayla',
#   'enlem': '39.272491',
#   'boylam': '36.750980',
#   'ulke': 'TR'},
#  {'ID': '323887',
#   'isim': 'Altinyayla',
#   'enlem': '36.997219',
#   'boylam': '29.545790',
#   'ulke': 'TR'},
#  {'ID': '323906',
#   'isim': 'Fatikli',
#   'enlem': '36.115002',
#   'boylam': '36.248169',
#   'ulke': 'TR'},
#  {'ID': '323921',
#   'isim': 'Altinkum',
#   'enlem': '38.264252',
#   'boylam': '41.061119',
#   'ulke': 'TR'},
#  {'ID': '323927',
#   'isim': 'Altinhisar',
#   'enlem': '37.991589',
#   'boylam': '34.373341',
#   'ulke': 'TR'},
#  {'ID': '323930',
#   'isim': 'Altinekin',
#   'enlem': '38.307781',
#   'boylam': '32.868610',
#   'ulke': 'TR'},
#  {'ID': '323963',
#   'isim': 'Alpu',
#   'enlem': '39.769032',
#   'boylam': '30.960600',
#   'ulke': 'TR'},
#  {'ID': '324294',
#   'isim': 'Alacati',
#   'enlem': '38.282459',
#   'boylam': '26.374590',
#   'ulke': 'TR'},
#  {'ID': '324315',
#   'isim': 'Turluk',
#   'enlem': '39.440338',
#   'boylam': '39.877731',
#   'ulke': 'TR'},
#  {'ID': '324470',
#   'isim': 'Aksu',
#   'enlem': '37.798889',
#   'boylam': '31.071110',
#   'ulke': 'TR'},
#  {'ID': '324486',
#   'isim': 'Akseki',
#   'enlem': '37.048611',
#   'boylam': '31.790001',
#   'ulke': 'TR'},
#  {'ID': '324630',
#   'isim': 'Akkoy',
#   'enlem': '37.956940',
#   'boylam': '29.078140',
#   'ulke': 'TR'},
#  {'ID': '324643',
#   'isim': 'Akkisla',
#   'enlem': '39.002220',
#   'boylam': '36.173809',
#   'ulke': 'TR'},
#  {'ID': '324953',
#   'isim': 'Akcadag',
#   'enlem': '38.345280',
#   'boylam': '37.967220',
#   'ulke': 'TR'},
#  {'ID': '325028',
#   'isim': 'Akarsu',
#   'enlem': '37.235489',
#   'boylam': '41.060680',
#   'ulke': 'TR'},
#  {'ID': '325066',
#   'isim': 'Ahmetli',
#   'enlem': '38.519600',
#   'boylam': '27.938650',
#   'ulke': 'TR'},
#  {'ID': '325171',
#   'isim': 'Aglasun',
#   'enlem': '37.649441',
#   'boylam': '30.534170',
#   'ulke': 'TR'},
#  {'ID': '325183',
#   'isim': 'Agin',
#   'enlem': '38.945190',
#   'boylam': '38.711979',
#   'ulke': 'TR'},
#  {'ID': '325269',
#   'isim': 'Agacoren',
#   'enlem': '38.874840',
#   'boylam': '33.916740',
#   'ulke': 'TR'},
#  {'ID': '325420',
#   'isim': 'Acirli',
#   'enlem': '37.457298',
#   'boylam': '41.296860',
#   'ulke': 'TR'},
#  {'ID': '325449',
#   'isim': 'Dobada',
#   'enlem': '38.550282',
#   'boylam': '34.509171',
#   'ulke': 'TR'},
#  {'ID': '392066',
#   'isim': 'Yemisli',
#   'enlem': '37.372921',
#   'boylam': '43.075859',
#   'ulke': 'TR'},
#  {'ID': '415534',
#   'isim': 'Nurdagi',
#   'enlem': '37.177299',
#   'boylam': '36.741940',
#   'ulke': 'TR'},
#  {'ID': '436138',
#   'isim': 'Yesildere',
#   'enlem': '36.985279',
#   'boylam': '37.507221',
#   'ulke': 'TR'},
#  {'ID': '436507',
#   'isim': 'Mahmutlar',
#   'enlem': '36.949001',
#   'boylam': '36.192310',
#   'ulke': 'TR'},
#  {'ID': '438046',
#   'isim': 'Kuzeytepe',
#   'enlem': '36.265560',
#   'boylam': '36.151669',
#   'ulke': 'TR'},
#  {'ID': '438056',
#   'isim': 'Kastal',
#   'enlem': '36.245972',
#   'boylam': '36.245079',
#   'ulke': 'TR'},
#  {'ID': '438096',
#   'isim': 'Toygarli',
#   'enlem': '36.214458',
#   'boylam': '36.070782',
#   'ulke': 'TR'},
#  {'ID': '438116',
#   'isim': 'Gumusgoze',
#   'enlem': '36.154869',
#   'boylam': '36.138699',
#   'ulke': 'TR'},
#  {'ID': '438119',
#   'isim': 'Dursunlu',
#   'enlem': '36.162781',
#   'boylam': '36.159721',
#   'ulke': 'TR'},
#  {'ID': '438122',
#   'isim': 'Asagiokcular',
#   'enlem': '36.183922',
#   'boylam': '36.136959',
#   'ulke': 'TR'},
#  {'ID': '438158',
#   'isim': 'Uzunbag',
#   'enlem': '36.148319',
#   'boylam': '36.024719',
#   'ulke': 'TR'},
#  {'ID': '438184',
#   'isim': 'Hacipasa',
#   'enlem': '36.078171',
#   'boylam': '36.384048',
#   'ulke': 'TR'},
#  {'ID': '438236',
#   'isim': 'Anayazi',
#   'enlem': '36.314442',
#   'boylam': '36.199169',
#   'ulke': 'TR'},
#  {'ID': '438241',
#   'isim': 'Buyukdalyan',
#   'enlem': '36.277710',
#   'boylam': '36.199211',
#   'ulke': 'TR'},
#  {'ID': '438243',
#   'isim': 'Gunyazi',
#   'enlem': '36.235062',
#   'boylam': '36.116150',
#   'ulke': 'TR'},
#  {'ID': '438245',
#   'isim': 'Tepehan',
#   'enlem': '36.158531',
#   'boylam': '36.228600',
#   'ulke': 'TR'},
#  {'ID': '439101',
#   'isim': 'Pekmezli',
#   'enlem': '36.753609',
#   'boylam': '39.450001',
#   'ulke': 'TR'},
#  {'ID': '447049',
#   'isim': 'Basyayla',
#   'enlem': '36.753368',
#   'boylam': '32.680180',
#   'ulke': 'TR'},
#  {'ID': '737119',
#   'isim': 'Yuvacik',
#   'enlem': '40.688148',
#   'boylam': '29.967381',
#   'ulke': 'TR'},
#  {'ID': '737140',
#   'isim': 'Yusufeli',
#   'enlem': '40.820351',
#   'boylam': '41.544300',
#   'ulke': 'TR'},
#  {'ID': '737529',
#   'isim': 'Yesilyurt',
#   'enlem': '40.327862',
#   'boylam': '36.351440',
#   'ulke': 'TR'},
#  {'ID': '737660',
#   'isim': 'Yenikoy',
#   'enlem': '40.535679',
#   'boylam': '29.353640',
#   'ulke': 'TR'},
#  {'ID': '737709',
#   'isim': 'Yenicekoy',
#   'enlem': '40.087780',
#   'boylam': '29.421940',
#   'ulke': 'TR'},
#  {'ID': '737756',
#   'isim': 'Yenicaga',
#   'enlem': '40.771149',
#   'boylam': '32.033749',
#   'ulke': 'TR'},
#  {'ID': '737980',
#   'isim': 'Yaprakli',
#   'enlem': '40.757851',
#   'boylam': '33.778191',
#   'ulke': 'TR'},
#  {'ID': '738055',
#   'isim': 'Yalakdere',
#   'enlem': '40.604721',
#   'boylam': '29.563890',
#   'ulke': 'TR'},
#  {'ID': '738085',
#   'isim': 'Yakakent',
#   'enlem': '41.632500',
#   'boylam': '35.528889',
#   'ulke': 'TR'},
#  {'ID': '738124',
#   'isim': 'Yaglidere',
#   'enlem': '40.545010',
#   'boylam': '39.531670',
#   'ulke': 'TR'},
#  {'ID': '738276',
#   'isim': 'Uzundere',
#   'enlem': '40.530140',
#   'boylam': '41.558441',
#   'ulke': 'TR'},
#  {'ID': '738372',
#   'isim': 'Umurbey',
#   'enlem': '40.414719',
#   'boylam': '29.183060',
#   'ulke': 'TR'},
#  {'ID': '738444',
#   'isim': 'Ulubey',
#   'enlem': '40.872139',
#   'boylam': '37.758759',
#   'ulke': 'TR'},
#  {'ID': '738457',
#   'isim': 'Ulasli',
#   'enlem': '40.705830',
#   'boylam': '29.696079',
#   'ulke': 'TR'},
#  {'ID': '738468',
#   'isim': 'Ugurludag',
#   'enlem': '40.446320',
#   'boylam': '34.452591',
#   'ulke': 'TR'},
#  {'ID': '738614',
#   'isim': 'Turkeli',
#   'enlem': '41.947639',
#   'boylam': '34.338612',
#   'ulke': 'TR'},
#  {'ID': '738674',
#   'isim': 'Tortum',
#   'enlem': '40.297298',
#   'boylam': '41.547710',
#   'ulke': 'TR'},
#  {'ID': '738715',
#   'isim': 'Tonya',
#   'enlem': '40.886250',
#   'boylam': '39.292381',
#   'ulke': 'TR'},
#  {'ID': '738962',
#   'isim': 'Tavsanli',
#   'enlem': '40.818760',
#   'boylam': '29.511360',
#   'ulke': 'TR'},
#  {'ID': '738965',
#   'isim': 'Tavsancil',
#   'enlem': '40.770828',
#   'boylam': '29.571939',
#   'ulke': 'TR'},
#  {'ID': '739067',
#   'isim': 'Taskopru',
#   'enlem': '40.673611',
#   'boylam': '29.391109',
#   'ulke': 'TR'},
#  {'ID': '739161',
#   'isim': 'Tacir',
#   'enlem': '40.525558',
#   'boylam': '29.739719',
#   'ulke': 'TR'},
#  {'ID': '739201',
#   'isim': 'Susuz',
#   'enlem': '40.778820',
#   'boylam': '43.146622',
#   'ulke': 'TR'},
#  {'ID': '739318',
#   'isim': 'Sulakyurt',
#   'enlem': '40.157330',
#   'boylam': '33.716000',
#   'ulke': 'TR'},
#  {'ID': '739425',
#   'isim': 'Sogutlu',
#   'enlem': '40.905899',
#   'boylam': '30.474480',
#   'ulke': 'TR'},
#  {'ID': '739574',
#   'isim': 'Siran',
#   'enlem': '40.189442',
#   'boylam': '39.126671',
#   'ulke': 'TR'},
#  {'ID': '739742',
#   'isim': 'Seydiler',
#   'enlem': '41.620049',
#   'boylam': '33.718151',
#   'ulke': 'TR'},
#  {'ID': '739838',
#   'isim': 'Selimpasa',
#   'enlem': '41.055840',
#   'boylam': '28.378950',
#   'ulke': 'TR'},
#  {'ID': '739917',
#   'isim': 'Seben',
#   'enlem': '40.411339',
#   'boylam': '31.573589',
#   'ulke': 'TR'},
#  {'ID': '739950',
#   'isim': 'Savsat',
#   'enlem': '41.240269',
#   'boylam': '42.361092',
#   'ulke': 'TR'},
#  {'ID': '740303',
#   'isim': 'Salpazari',
#   'enlem': '40.941109',
#   'boylam': '39.195560',
#   'ulke': 'TR'},
#  {'ID': '740462',
#   'isim': 'Sabanozu',
#   'enlem': '40.482491',
#   'boylam': '33.283520',
#   'ulke': 'TR'},
#  {'ID': '740531',
#   'isim': 'Posof',
#   'enlem': '41.511108',
#   'boylam': '42.729172',
#   'ulke': 'TR'},
#  {'ID': '740561',
#   'isim': 'Nefsipiraziz',
#   'enlem': '40.933331',
#   'boylam': '38.133331',
#   'ulke': 'TR'},
#  {'ID': '740570',
#   'isim': 'Pinarhisar',
#   'enlem': '41.624168',
#   'boylam': '27.520000',
#   'ulke': 'TR'},
#  {'ID': '740581',
#   'isim': 'Pinarbasi',
#   'enlem': '41.603882',
#   'boylam': '33.110989',
#   'ulke': 'TR'},
#  {'ID': '740605',
#   'isim': 'Persembe',
#   'enlem': '41.065559',
#   'boylam': '37.771389',
#   'ulke': 'TR'},
#  {'ID': '740650',
#   'isim': 'Pehlivankoy',
#   'enlem': '41.348122',
#   'boylam': '26.925220',
#   'ulke': 'TR'},
#  {'ID': '740659',
#   'isim': 'Pazaryolu',
#   'enlem': '40.420830',
#   'boylam': '40.771042',
#   'ulke': 'TR'},
#  {'ID': '740677',
#   'isim': 'Pazar',
#   'enlem': '40.276520',
#   'boylam': '36.283470',
#   'ulke': 'TR'},
#  {'ID': '740940',
#   'isim': 'Ortakoy',
#   'enlem': '41.101540',
#   'boylam': '28.375879',
#   'ulke': 'TR'},
#  {'ID': '741002',
#   'isim': 'Orta',
#   'enlem': '40.624199',
#   'boylam': '33.109280',
#   'ulke': 'TR'},
#  {'ID': '741136',
#   'isim': 'Olur',
#   'enlem': '40.821640',
#   'boylam': '42.128460',
#   'ulke': 'TR'},
#  {'ID': '741330',
#   'isim': 'Narman',
#   'enlem': '40.346531',
#   'boylam': '41.870270',
#   'ulke': 'TR'},
#  {'ID': '741335',
#   'isim': 'Narlica',
#   'enlem': '40.385830',
#   'boylam': '29.481110',
#   'ulke': 'TR'},
#  {'ID': '741484',
#   'isim': 'Mudurnu',
#   'enlem': '40.473000',
#   'boylam': '31.207550',
#   'ulke': 'TR'},
#  {'ID': '741538',
#   'isim': 'Mihalgazi',
#   'enlem': '40.026211',
#   'boylam': '30.577070',
#   'ulke': 'TR'},
#  {'ID': '741570',
#   'isim': 'Mesudiye',
#   'enlem': '40.462502',
#   'boylam': '37.772499',
#   'ulke': 'TR'},
#  {'ID': '741628',
#   'isim': 'Meric',
#   'enlem': '41.191830',
#   'boylam': '26.420971',
#   'ulke': 'TR'},
#  {'ID': '741692',
#   'isim': 'Mecitozu',
#   'enlem': '40.520000',
#   'boylam': '35.295280',
#   'ulke': 'TR'},
#  {'ID': '741725',
#   'isim': 'Marmaraereglisi',
#   'enlem': '40.970032',
#   'boylam': '27.955280',
#   'ulke': 'TR'},
#  {'ID': '741730',
#   'isim': 'Marmara',
#   'enlem': '40.586330',
#   'boylam': '27.555410',
#   'ulke': 'TR'},
#  {'ID': '741878',
#   'isim': 'Lapseki',
#   'enlem': '40.344170',
#   'boylam': '26.685560',
#   'ulke': 'TR'},
#  {'ID': '741884',
#   'isim': 'Lalapasa',
#   'enlem': '41.839512',
#   'boylam': '26.735609',
#   'ulke': 'TR'},
#  {'ID': '741892',
#   'isim': 'Ladik',
#   'enlem': '40.910561',
#   'boylam': '35.891941',
#   'ulke': 'TR'},
#  {'ID': '742095',
#   'isim': 'Kurucasile',
#   'enlem': '41.837811',
#   'boylam': '32.716209',
#   'ulke': 'TR'},
#  {'ID': '742164',
#   'isim': 'Kursunlu',
#   'enlem': '40.841011',
#   'boylam': '33.260281',
#   'ulke': 'TR'},
#  {'ID': '742171',
#   'isim': 'Kursunlu',
#   'enlem': '40.033611',
#   'boylam': '29.664721',
#   'ulke': 'TR'},
#  {'ID': '742189',
#   'isim': 'Kure',
#   'enlem': '41.805779',
#   'boylam': '33.711609',
#   'ulke': 'TR'},
#  {'ID': '742266',
#   'isim': 'Kumburgaz',
#   'enlem': '41.021069',
#   'boylam': '28.477150',
#   'ulke': 'TR'},
#  {'ID': '742292',
#   'isim': 'Kullar',
#   'enlem': '40.725739',
#   'boylam': '29.972300',
#   'ulke': 'TR'},
#  {'ID': '742348',
#   'isim': 'Kucukkumla',
#   'enlem': '40.477371',
#   'boylam': '29.123060',
#   'ulke': 'TR'},
#  {'ID': '742499',
#   'isim': 'Koyulhisar',
#   'enlem': '40.302502',
#   'boylam': '37.831108',
#   'ulke': 'TR'},
#  {'ID': '742588',
#   'isim': 'Kosekoy',
#   'enlem': '40.753391',
#   'boylam': '30.030199',
#   'ulke': 'TR'},
#  {'ID': '742606',
#   'isim': 'Kose',
#   'enlem': '40.209999',
#   'boylam': '39.651112',
#   'ulke': 'TR'},
#  {'ID': '742617',
#   'isim': 'Koru',
#   'enlem': '40.654350',
#   'boylam': '29.162901',
#   'ulke': 'TR'},
#  {'ID': '742657',
#   'isim': 'Korgun',
#   'enlem': '40.734798',
#   'boylam': '33.518440',
#   'ulke': 'TR'},
#  {'ID': '742686',
#   'isim': 'Koprubasi',
#   'enlem': '40.808578',
#   'boylam': '40.123760',
#   'ulke': 'TR'},
#  {'ID': '742987',
#   'isim': 'Kizilirmak',
#   'enlem': '40.345558',
#   'boylam': '33.986389',
#   'ulke': 'TR'},
#  {'ID': '743256',
#   'isim': 'Kirazli',
#   'enlem': '40.099720',
#   'boylam': '29.042780',
#   'ulke': 'TR'},
#  {'ID': '743382',
#   'isim': 'Kibriscik',
#   'enlem': '40.407780',
#   'boylam': '31.851940',
#   'ulke': 'TR'},
#  {'ID': '743438',
#   'isim': 'Kesap',
#   'enlem': '40.916389',
#   'boylam': '38.514439',
#   'ulke': 'TR'},
#  {'ID': '743616',
#   'isim': 'Kaytazdere',
#   'enlem': '40.682251',
#   'boylam': '29.532360',
#   'ulke': 'TR'},
#  {'ID': '743851',
#   'isim': 'Kavak',
#   'enlem': '41.078331',
#   'boylam': '36.042500',
#   'ulke': 'TR'},
#  {'ID': '744514',
#   'isim': 'Karacakoy',
#   'enlem': '41.402859',
#   'boylam': '28.383381',
#   'ulke': 'TR'},
#  {'ID': '744767',
#   'isim': 'Kalkandere',
#   'enlem': '40.928040',
#   'boylam': '40.441898',
#   'ulke': 'TR'},
#  {'ID': '744814',
#   'isim': 'Kalecik',
#   'enlem': '40.097221',
#   'boylam': '33.408329',
#   'ulke': 'TR'},
#  {'ID': '744958',
#   'isim': 'Kabatas',
#   'enlem': '40.750000',
#   'boylam': '37.450001',
#   'ulke': 'TR'},
#  {'ID': '745007',
#   'isim': 'Kabaduz',
#   'enlem': '40.859718',
#   'boylam': '37.889999',
#   'ulke': 'TR'},
#  {'ID': '745030',
#   'isim': 'Iyidere',
#   'enlem': '41.011921',
#   'boylam': '40.361851',
#   'ulke': 'TR'},
#  {'ID': '745164',
#   'isim': 'Inhisar',
#   'enlem': '40.049320',
#   'boylam': '30.385210',
#   'ulke': 'TR'},
#  {'ID': '745364',
#   'isim': 'Ikizce',
#   'enlem': '41.058331',
#   'boylam': '37.080280',
#   'ulke': 'TR'},
#  {'ID': '745383',
#   'isim': 'Ihsaniye',
#   'enlem': '40.690868',
#   'boylam': '29.834721',
#   'ulke': 'TR'},
#  {'ID': '745387',
#   'isim': 'Ihsangazi',
#   'enlem': '41.204319',
#   'boylam': '33.554550',
#   'ulke': 'TR'},
#  {'ID': '745665',
#   'isim': 'Nurluca',
#   'enlem': '41.022678',
#   'boylam': '40.898338',
#   'ulke': 'TR'},
#  {'ID': '745693',
#   'isim': 'Hayrat',
#   'enlem': '40.888439',
#   'boylam': '40.369862',
#   'ulke': 'TR'},
#  {'ID': '745884',
#   'isim': 'Hanonu',
#   'enlem': '41.627048',
#   'boylam': '34.466671',
#   'ulke': 'TR'},
#  {'ID': '745903',
#   'isim': 'Hanak',
#   'enlem': '41.233608',
#   'boylam': '42.847221',
#   'ulke': 'TR'},
#  {'ID': '746308',
#   'isim': 'Guneysu',
#   'enlem': '40.977619',
#   'boylam': '40.613590',
#   'ulke': 'TR'},
#  {'ID': '746426',
#   'isim': 'Gumushacikoy',
#   'enlem': '40.873058',
#   'boylam': '35.214722',
#   'ulke': 'TR'},
#  {'ID': '746497',
#   'isim': 'Gudul',
#   'enlem': '40.210510',
#   'boylam': '32.245522',
#   'ulke': 'TR'},
#  {'ID': '746546',
#   'isim': 'Goynuk',
#   'enlem': '40.400280',
#   'boylam': '30.788330',
#   'ulke': 'TR'},
#  {'ID': '746547',
#   'isim': 'Goynucek',
#   'enlem': '40.399170',
#   'boylam': '35.525002',
#   'ulke': 'TR'},
#  {'ID': '746602',
#   'isim': 'Golpazari',
#   'enlem': '40.284721',
#   'boylam': '30.317221',
#   'ulke': 'TR'},
#  {'ID': '746603',
#   'isim': 'Golova',
#   'enlem': '40.061939',
#   'boylam': '38.606670',
#   'ulke': 'TR'},
#  {'ID': '746643',
#   'isim': 'Merdinik',
#   'enlem': '40.793610',
#   'boylam': '42.609169',
#   'ulke': 'TR'},
#  {'ID': '746712',
#   'isim': 'Murgul',
#   'enlem': '41.274441',
#   'boylam': '41.566109',
#   'ulke': 'TR'},
#  {'ID': '746913',
#   'isim': 'Gerze',
#   'enlem': '41.803612',
#   'boylam': '35.201111',
#   'ulke': 'TR'},
#  {'ID': '747191',
#   'isim': 'Eynesil',
#   'enlem': '41.064529',
#   'boylam': '39.143799',
#   'ulke': 'TR'},
#  {'ID': '747217',
#   'isim': 'Evren',
#   'enlem': '40.244320',
#   'boylam': '39.175331',
#   'ulke': 'TR'},
#  {'ID': '747263',
#   'isim': 'Gozyeri',
#   'enlem': '40.865959',
#   'boylam': '32.541672',
#   'ulke': 'TR'},
#  {'ID': '747449',
#   'isim': 'Erfelek',
#   'enlem': '41.879261',
#   'boylam': '34.918381',
#   'ulke': 'TR'},
#  {'ID': '747503',
#   'isim': 'Enez',
#   'enlem': '40.724720',
#   'boylam': '26.082500',
#   'ulke': 'TR'},
#  {'ID': '747618',
#   'isim': 'Eldivan',
#   'enlem': '40.529751',
#   'boylam': '33.499039',
#   'ulke': 'TR'},
#  {'ID': '747630',
#   'isim': 'Elbeyli',
#   'enlem': '40.486111',
#   'boylam': '29.724720',
#   'ulke': 'TR'},
#  {'ID': '747705',
#   'isim': 'Eflani',
#   'enlem': '41.422890',
#   'boylam': '32.957611',
#   'ulke': 'TR'},
#  {'ID': '747728',
#   'isim': 'Eceabat',
#   'enlem': '40.184158',
#   'boylam': '26.357401',
#   'ulke': 'TR'},
#  {'ID': '747751',
#   'isim': 'Duzkoy',
#   'enlem': '40.872841',
#   'boylam': '39.427158',
#   'ulke': 'TR'},
#  {'ID': '747793',
#   'isim': 'Durusu',
#   'enlem': '41.305279',
#   'boylam': '28.676670',
#   'ulke': 'TR'},
#  {'ID': '747826',
#   'isim': 'Duragan',
#   'enlem': '41.415829',
#   'boylam': '35.054440',
#   'ulke': 'TR'},
#  {'ID': '747899',
#   'isim': 'Dortdivan',
#   'enlem': '40.720520',
#   'boylam': '32.063141',
#   'ulke': 'TR'},
#  {'ID': '747912',
#   'isim': 'Dongel',
#   'enlem': '40.693600',
#   'boylam': '29.941540',
#   'ulke': 'TR'},
#  {'ID': '747986',
#   'isim': 'Dogansar',
#   'enlem': '40.216671',
#   'boylam': '37.533329',
#   'ulke': 'TR'},
#  {'ID': '748008',
#   'isim': 'Dogankent',
#   'enlem': '40.807499',
#   'boylam': '38.917221',
#   'ulke': 'TR'},
#  {'ID': '748166',
#   'isim': 'Devrekani',
#   'enlem': '41.603031',
#   'boylam': '33.839218',
#   'ulke': 'TR'},
#  {'ID': '748200',
#   'isim': 'Dernekpazari',
#   'enlem': '40.802860',
#   'boylam': '40.239578',
#   'ulke': 'TR'},
#  {'ID': '748240',
#   'isim': 'Dereli',
#   'enlem': '40.737801',
#   'boylam': '38.449341',
#   'ulke': 'TR'},
#  {'ID': '748378',
#   'isim': 'Demirtas',
#   'enlem': '40.271938',
#   'boylam': '29.098330',
#   'ulke': 'TR'},
#  {'ID': '748688',
#   'isim': 'Damal',
#   'enlem': '41.340351',
#   'boylam': '42.839359',
#   'ulke': 'TR'},
#  {'ID': '748761',
#   'isim': 'Daday',
#   'enlem': '41.478661',
#   'boylam': '33.466671',
#   'ulke': 'TR'},
#  {'ID': '749075',
#   'isim': 'Cinarcik',
#   'enlem': '40.641201',
#   'boylam': '29.145981',
#   'ulke': 'TR'},
#  {'ID': '749263',
#   'isim': 'Cerrah',
#   'enlem': '40.071239',
#   'boylam': '29.446609',
#   'ulke': 'TR'},
#  {'ID': '749392',
#   'isim': 'Cekerek',
#   'enlem': '40.073059',
#   'boylam': '35.494720',
#   'ulke': 'TR'},
#  {'ID': '749421',
#   'isim': 'Kurtun',
#   'enlem': '40.670921',
#   'boylam': '39.143608',
#   'ulke': 'TR'},
#  {'ID': '749456',
#   'isim': 'Caykara',
#   'enlem': '40.754810',
#   'boylam': '40.235519',
#   'ulke': 'TR'},
#  {'ID': '749740',
#   'isim': 'Canta',
#   'enlem': '41.118141',
#   'boylam': '28.080339',
#   'ulke': 'TR'},
#  {'ID': '749843',
#   'isim': 'Camlidere',
#   'enlem': '40.489578',
#   'boylam': '32.474991',
#   'ulke': 'TR'},
#  {'ID': '749916',
#   'isim': 'Camas',
#   'enlem': '40.901669',
#   'boylam': '37.528839',
#   'ulke': 'TR'},
#  {'ID': '750043',
#   'isim': 'Cakirli',
#   'enlem': '40.518059',
#   'boylam': '29.452221',
#   'ulke': 'TR'},
#  {'ID': '750165',
#   'isim': 'Lacin',
#   'enlem': '40.770180',
#   'boylam': '34.898380',
#   'ulke': 'TR'},
#  {'ID': '750228',
#   'isim': 'Buyukcavuslu',
#   'enlem': '41.242271',
#   'boylam': '28.064619',
#   'ulke': 'TR'},
#  {'ID': '750446',
#   'isim': 'Boyalik',
#   'enlem': '41.263371',
#   'boylam': '28.631420',
#   'ulke': 'TR'},
#  {'ID': '750450',
#   'isim': 'Boyalica',
#   'enlem': '40.481941',
#   'boylam': '29.560829',
#   'ulke': 'TR'},
#  {'ID': '750496',
#   'isim': 'Borcka',
#   'enlem': '41.363152',
#   'boylam': '41.676521',
#   'ulke': 'TR'},
#  {'ID': '750615',
#   'isim': 'Asarcik',
#   'enlem': '41.035561',
#   'boylam': '36.235561',
#   'ulke': 'TR'},
#  {'ID': '750874',
#   'isim': 'Bayramoren',
#   'enlem': '40.943291',
#   'boylam': '33.202999',
#   'ulke': 'TR'},
#  {'ID': '751036',
#   'isim': 'Basciftlik',
#   'enlem': '40.546940',
#   'boylam': '37.169170',
#   'ulke': 'TR'},
#  {'ID': '751277',
#   'isim': 'Bahcecik',
#   'enlem': '40.667290',
#   'boylam': '29.914881',
#   'ulke': 'TR'},
#  {'ID': '751388',
#   'isim': 'Azdavay',
#   'enlem': '41.642670',
#   'boylam': '33.299999',
#   'ulke': 'TR'},
#  {'ID': '751427',
#   'isim': 'Ayvacik',
#   'enlem': '40.991112',
#   'boylam': '36.631390',
#   'ulke': 'TR'},
#  {'ID': '751475',
#   'isim': 'Aydintepe',
#   'enlem': '40.389439',
#   'boylam': '40.150600',
#   'ulke': 'TR'},
#  {'ID': '751491',
#   'isim': 'Aydincik',
#   'enlem': '40.127270',
#   'boylam': '35.287651',
#   'ulke': 'TR'},
#  {'ID': '751511',
#   'isim': 'Ayas',
#   'enlem': '40.019329',
#   'boylam': '32.332211',
#   'ulke': 'TR'},
#  {'ID': '751516',
#   'isim': 'Ayancik',
#   'enlem': '41.944721',
#   'boylam': '34.586109',
#   'ulke': 'TR'},
#  {'ID': '751575',
#   'isim': 'Atkaracalar',
#   'enlem': '40.815929',
#   'boylam': '33.075562',
#   'ulke': 'TR'},
#  {'ID': '751818',
#   'isim': 'Artova',
#   'enlem': '40.115780',
#   'boylam': '36.300098',
#   'ulke': 'TR'},
#  {'ID': '751864',
#   'isim': 'Arpacay',
#   'enlem': '40.848701',
#   'boylam': '43.329109',
#   'ulke': 'TR'},
#  {'ID': '751976',
#   'isim': 'Arac',
#   'enlem': '41.242222',
#   'boylam': '33.327671',
#   'ulke': 'TR'},
#  {'ID': '752016',
#   'isim': 'Amasra',
#   'enlem': '41.746330',
#   'boylam': '32.386330',
#   'ulke': 'TR'},
#  {'ID': '752042',
#   'isim': 'Altinova',
#   'enlem': '40.694950',
#   'boylam': '29.509859',
#   'ulke': 'TR'},
#  {'ID': '752083',
#   'isim': 'Almus',
#   'enlem': '40.375832',
#   'boylam': '36.904442',
#   'ulke': 'TR'},
#  {'ID': '752188',
#   'isim': 'Alanyurt',
#   'enlem': '40.108810',
#   'boylam': '29.518709',
#   'ulke': 'TR'},
#  {'ID': '752284',
#   'isim': 'Akyurt',
#   'enlem': '40.135120',
#   'boylam': '33.086140',
#   'ulke': 'TR'},
#  {'ID': '752359',
#   'isim': 'Aksu',
#   'enlem': '40.089481',
#   'boylam': '38.035229',
#   'ulke': 'TR'},
#  {'ID': '752437',
#   'isim': 'Akkus',
#   'enlem': '40.793060',
#   'boylam': '37.016392',
#   'ulke': 'TR'},
#  {'ID': '752476',
#   'isim': 'Akincilar',
#   'enlem': '40.079720',
#   'boylam': '38.348061',
#   'ulke': 'TR'},
#  {'ID': '752926',
#   'isim': 'Abana',
#   'enlem': '41.978580',
#   'boylam': '34.011002',
#   'ulke': 'TR'},
#  {'ID': '857229',
#   'isim': 'Celaliye',
#   'enlem': '41.051880',
#   'boylam': '28.418671',
#   'ulke': 'TR'},
#  {'ID': '857230',
#   'isim': 'Muratbey',
#   'enlem': '41.096298',
#   'boylam': '28.492270',
#   'ulke': 'TR'},
#  {'ID': '862940',
#   'isim': 'Halidere',
#   'enlem': '40.716042',
#   'boylam': '29.752230',
#   'ulke': 'TR'},
#  {'ID': '6559490',
#   'isim': 'Demre',
#   'enlem': '36.253700',
#   'boylam': '29.977699',
#   'ulke': 'TR'},
#  {'ID': '6692526',
#   'isim': 'OEluedeniz',
#   'enlem': '36.566738',
#   'boylam': '29.144670',
#   'ulke': 'TR'},
#  {'ID': '6940491',
#   'isim': 'Arikoey',
#   'enlem': '41.230438',
#   'boylam': '29.004250',
#   'ulke': 'TR'},
#  {'ID': '6940561',
#   'isim': 'Catalhoeyuek',
#   'enlem': '37.668468',
#   'boylam': '32.826889',
#   'ulke': 'TR'},
#  {'ID': '7280504',
#   'isim': 'Yaniklar',
#   'enlem': '36.708271',
#   'boylam': '29.050810',
#   'ulke': 'TR'}]

# %% [raw]
# Eger boyle bir hata alırsanız:
#
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [raw]
# Cozum linki:
# https://stackoverflow.com/questions/43490495/how-to-set-notebookapp-iopub-data-rate-limit-and-others-notebookapp-settings-in

# %% [raw]
# anaconda prompt terminali kapatın.
# anaconda prompt terminali yeniden açın
# jupyter notebook yazmak yerine aşağıdaki komutu yazın:
# jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10
