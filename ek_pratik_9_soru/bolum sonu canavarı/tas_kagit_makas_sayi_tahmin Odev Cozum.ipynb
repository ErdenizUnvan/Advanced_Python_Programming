# %%
#bu kod ile oyunun tum kurallari saglaniyor.

# %%
import random
def menu():
    menuler = f"""
    1: Sayı Tahmin Oyunu,
    2: Taş, Kağıt, Makas Oyunu,
    3: Çıkış 
    """
    print(menuler)


def sayi_tahmin():
    rastgeleSayi = random.randint(1, 100)
    tahminSayisi = 0
    while True:
        try:
            sayi = input("1 ile 100 arasında bir sayı giriniz.")
            flag1=False
            while not sayi.isdigit() or int(sayi)>100 or int(sayi)<0:
                print('yanlis secim')
                sayi = input("1 ile 100 arasında bir sayı gir oyunu oynamak icin ya da ana menu icin ESC yaz.")
                if sayi.lower()=='esc':
                    print('ana menu')
                    flag1=True
                    break

            if flag1:
                break
                
            sayi=int(sayi)
            tahminSayisi += 1
            if sayi > rastgeleSayi:
                print("Daha küçük değerde tahminde bulunun")
                #continue
            elif sayi < rastgeleSayi:
                print("Daha büyük değerde tahminde bulunun")
                #continue
            else:
                print(f'Bingo. {tahminSayisi} adet hak kullanarak sayıyı bildiniz:{rastgeleSayi}.')
                tahminSayisi = 0
                rastgeleSayi = random.randint(1, 100)
                raise ValueError()
                
        except Exception as e:
            while True:
                devam = input('Yeniden oynamak icin E yaz ya da cikis icin ESC :')
                if devam.lower()=='esc':
                    print('Ana menu')
                    flag=True
                    break
                elif devam.lower()=='e':
                    print('devam')
                    flag=False
                    break
                else:
                    print('Yanlis secim yaptin. Sadece E ya da C yaz')
            if flag:
                break
            else:
                continue
            
def tas_kagit_makas():
    print("\n\tInsan VS Bilgisayar")
    while True:
        try:
            flag2=False
            #flag3=False
            player = input("\nSilahini sec: Tas, Kagit, Makas\n")
            player = player.lower()

            secenekler=['tas','kagit','makas']
            
            while not player in secenekler:
                print('Yanlis Secim')
                player = input("\nSilahini sec: Tas, Kagit, Makas\n ya da cikis icin ESC yaz: ").lower()
                if player=='esc':
                    print('ana menu')
                    flag2=True
                    break

            
            if flag2:
                break
                

            computer = random.choice(secenekler)
            computer = computer.lower()

            if player == computer:
                print(player," vs ",computer)
                print("Berabere!\n")
                raise ValueError()
            
            elif player == "tas":
                if computer == "kagit":
                    print(player," vs ",computer)
                    print("Kagit tasi cevreler! Kaybettin!\n")
                    raise ValueError()
                else:
                    print("Tas ezer",computer,". Kazandin!\n")
                    raise ValueError()
                    
            elif player == "kagit":
                if computer == "makas":
                    print(player," vs ",computer)
                    print("Makas kagiti keser! Kaybettin!\n")
                    raise ValueError()
                else:
                    print("Kagit cevreler",computer,". Kazandin!\n")
                    raise ValueError()

            elif player == "makas":
                if computer == "tas":
                    print(player," vs ",computer)
                    print("Tas makasi ezer! Kaybettin!\n")
                    raise ValueError()
                else:
                    print("Makas keser",computer,". Kazandin!\n")
                    raise ValueError()
        
        except Exception as e:
            #print('Yanlis veri')
            while True:
                devam = input('Yeniden oynamak icin E yaz ya da cikis icin ESC :')
                if devam.lower()=='esc':
                    print('Ana menu')
                    flag=True
                    break
                elif devam.lower()=='e':
                    print('devam')
                    flag=False
                    break
                else:
                    print('Yanlis secim yaptin. Sadece E ya da C yaz')
            if flag:
                break
            else:
                continue
        
    
while(True):
    menu()
    try:
        option = int(input('Seçiminiz : '))
        if option <1 or option >3:
            raise ValueError('Yanlis Secim')
    except Exception as e:
        print('Hatali seçim')
    else:
        if option == 1:
            sayi_tahmin()
        elif option == 2:
            tas_kagit_makas()
        elif option == 3:
            print('Çıkış yapılıyor...')
            break
# Out:
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : -1
# Hatali seçim
#
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : 4
# Hatali seçim
#
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : tahta
# Hatali seçim
#
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : $  312  dwed ed
# Hatali seçim
#
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : 1
# 1 ile 100 arasında bir sayı giriniz.101
# yanlis secim
# 1 ile 100 arasında bir sayı gir oyunu oynamak icin ya da ana menu icin ESC yaz.Esc
# ana menu
#
#     1: Sayı Tahmin Oyunu,
#     2: Taş, Kağıt, Makas Oyunu,
#     3: Çıkış
#
# Seçiminiz : 1
# 1 ile 100 arasında bir sayı giriniz.500
# yanlis secim
# 1 ile 100 arasında bir sayı gir oyunu oynamak icin ya da ana menu icin ESC yaz.50
# Daha küçük değerde tahminde bulunun
# ...

# %%
#chatgpt'nin yazdığı kod aşağıdadır. Ama bu kod oyunun kurallarına uymuyor. Butun kosullar saglanmiyor.

# %%
import random

def sayi_tahmin_oyunu():
    print("\n1 ile 100 arasında bir sayı giriniz.")
    rastgele_sayi = random.randint(1, 100)
    tahmin_sayisi = 0

    while True:
        tahmin = input()
        if tahmin.lower() == 'esc':
            print("Ana menü")
            return
        if not tahmin.isdigit() or not 1 <= int(tahmin) <= 100:
            print("Yanlış seçim\n1 ile 100 arasında bir sayı gir oyunu oynamak için ya da ana menü için ESC yaz.")
            continue
        
        tahmin_sayisi += 1
        tahmin = int(tahmin)

        if tahmin < rastgele_sayi:
            print("Daha büyük değerde tahminde bulunun")
        elif tahmin > rastgele_sayi:
            print("Daha küçük değerde tahminde bulunun")
        else:
            print(f"Bingo. {tahmin_sayisi} adet hak kullanarak sayıyı bildiniz: {tahmin}.")
            break

def tas_kagit_makas():
    secenekler = ["Tas", "Kagit", "Makas"]

    while True:
        secim = input("\nSilahini sec: Tas, Kagit, Makas ya da çıkış için ESC yaz: ")
        if secim.lower() == 'esc':
            print("Ana menü")
            return
        if secim.capitalize() not in secenekler:
            print("Yanlış Seçim")
            continue

        bilgisayar_secimi = random.choice(secenekler)
        print(f"{secim}  vs  {bilgisayar_secimi}")
        if secim == bilgisayar_secimi:
            print("Berabere!")
        else:
            kazanan = "Insan" if (secim == "Tas" and bilgisayar_secimi == "Makas") or \
                               (secim == "Kagit" and bilgisayar_secimi == "Tas") or \
                               (secim == "Makas" and bilgisayar_secimi == "Kagit") else "Bilgisayar"
            print(f"{kazanan} kazandı!")

def ana_menu():
    while True:
        print("\n    1: Sayı Tahmin Oyunu,\n    2: Taş, Kağıt, Makas Oyunu,\n    3: Çıkış ")
        secim = input("Seçiminiz : ")

        if secim == '1':
            sayi_tahmin_oyunu()
        elif secim == '2':
            tas_kagit_makas()
        elif secim == '3':
            print("Çıkış yapılıyor...")
            break
        else:
            print("Hatalı seçim")

ana_menu()
